# %% [markdown]
# # [CHASEDB1] FRU-Net -- AGG FOLD LOOPS -- seed 1337

# %%
import sys, os
sys.path.append(os.path.abspath('../../'))
sys.path.append(os.path.abspath('../../../FR-UNet/'))

print( os.getcwd())
sys.path
# Out:
# c:\Users\s1005\OneDrive\文件\PLM_DOCS\code\githubs\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation\notebooks\train_all
# ['C:\\Users\\s1005\\AppData\\Local\\Programs\\Python\\Python310\\python310.zip',
#  'C:\\Users\\s1005\\AppData\\Local\\Programs\\Python\\Python310\\DLLs',
#  'C:\\Users\\s1005\\AppData\\Local\\Programs\\Python\\Python310\\lib',
#  'C:\\Users\\s1005\\AppData\\Local\\Programs\\Python\\Python310',
#  'c:\\Users\\s1005\\OneDrive\\文件\\PLM_DOCS\\code\\githubs\\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation\\venv310',
#  '',
#  'c:\\Users\\s1005\\OneDrive\\文件\\PLM_DOCS\\code\\githubs\\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation\\venv310\\lib\\site-packages',
#  'c:\\Users\\s1005\\OneDrive\\文件\\PLM_DOCS\\code\\githubs\\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation',
#  'c:\\Users\\s1005\\OneDrive\\文件\\PLM_DOCS\\code\\githubs\\FR-UNet']

# %%
from src.models.unet import UNet
print(UNet)
# Out:
# <class 'src.models.unet.UNet'>

# %%
from pathlib import Path
import torch
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# # CHANGE THESE

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
SEED   = 1337
DATASET = "CHASEDB1" # "DRIVE" | "STARE" | "CHASEDB1"

PATCH_SIZE = 128
VAL_WINDOW  = PATCH_SIZE
VAL_OVERLAP = 0.25

VESSEL_BIAS=0.7
MIN_PERCENT_VESSEL=0.008
V_MULT=30
DENSE_BIAS=None
BATCH_SIZE=2

IMG_SIZE=512

EPOCHS = 50
warmup_epochs = 5

FOLDS = 5
FOLD_ID = 3

THRESHOLD_EVAL = 0.5


MODEL_NAME = "FR-UNet"
TITLE     = f"[{DATASET}] {MODEL_NAME} NEW SPLIT ({FOLDS} folds) -- seed 1337 -- DPCN 6x64 hl=2 reduce=64 cbam=16 epochs={EPOCHS}"
SAVE_ROOT = Path(f"../../../../pth/{MODEL_NAME}_{DATASET}_NEWSPLIT")     # a clean experiment folder
SAVE_CKPT = SAVE_ROOT / "checkpoints"
SAVE_PRED = SAVE_ROOT / "predictions"   # per-image logits/prob/masks
SAVE_VIZ  = SAVE_ROOT / "visuals"       # PNG overlays per test image
SAVE_LOGS = SAVE_ROOT / "logs"
for d in [SAVE_ROOT, SAVE_CKPT, SAVE_PRED, SAVE_VIZ, SAVE_LOGS]: d.mkdir(parents=True, exist_ok=True)

DATASET_ROOT        = f"../../../../Retinal_Vessel_Segmentation_Datasets/{DATASET}/"
DATASET_LABELFOLDER = "1st_manual"

# %% [markdown]
# # IMPORTS

# %%
import os, json, math, time, random
from pathlib import Path
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import LambdaLR
import matplotlib.pyplot as plt

# --- data utils ---
from src.data.splits import (
    split_drive_20_20,
    split_chase_subjectwise_20_8,
    split_stare_leave_one_out,
    stare_loo_fold,
    chase_mc_balanced_splits,
    drive_random_20_20,

    chase_random_subject_split,

)

from src.data.dataloader import make_loaders
from src.data.augmentations import get_train_augs, get_val_augs

# use YOUR metrics utilities
from src.training.metrics import (
    confusion_counts,
    dice as dice_metric,
    iou as iou_metric,
    roc_auc as roc_auc_metric,
    pr_auc as pr_auc_metric,
    acc_from_counts,
    recall_from_counts,          # sensitivity
    specificity_from_counts,     # specificity
    cldice
)



# --- evaluation & visualization ---
from src.evaluation.evaluate import evaluate_and_print
from src.evaluation.visualization import visualize_samples

# %%
def eval_leftout_with_fov(prob_1chw: torch.Tensor,
                          gt_1chw: torch.Tensor,
                          fov_1chw: torch.Tensor,
                          thr: float = 0.5) -> dict:
    """
    Evaluate one test image (left out) using *your* metrics helpers.
    All metrics are computed *within FOV*.
    """
    # to cpu numpy
    p = prob_1chw.squeeze().detach().cpu().numpy()       # [H,W] probs in [0,1]
    g = gt_1chw.squeeze().detach().cpu().numpy()         # [H,W] {0,1}
    f = fov_1chw.squeeze().detach().cpu().numpy()        # [H,W] {0,1}

    # clamp to FOV (zero-out everything outside)
    p_f = p * (f > 0.5)
    g_f = (g > 0.5).astype(np.uint8)

    # binarize at thr (inside FOV)
    pred_f = (p_f >= thr).astype(np.uint8)

    # counts + derived metrics
    tp, fp, tn, fn = confusion_counts(pred_f, g_f)

    ACC  = float(acc_from_counts(tp, fp, tn, fn))
    SEN  = float(recall_from_counts(tp, fn))        # sensitivity / TPR
    SPE  = float(specificity_from_counts(tn, fp))
    DICE = float(dice_metric(pred_f, g_f))
    IOU  = float(iou_metric(pred_f, g_f))
    CLDICE = float(cldice(pred_f, g_f))

    # probability-based (AUCs) computed on FOV-masked prob/gt
    try:
        AUC = float(roc_auc_metric(p_f, g_f))
    except Exception:
        AUC = float("nan")
    try:
        AP = float(pr_auc_metric(p_f, g_f))
    except Exception:
        AP = float("nan")

    return dict(ACC=ACC, Dice=DICE, IoU=IOU, SEN=SEN, SPE=SPE, AUC=AUC, AP=AP,CLDICE=CLDICE,
                tp=int(tp), fp=int(fp), tn=int(tn), fn=int(fn))

# %% [markdown]
# # helpers and config

# %%
os.getcwd()
# Out:
# 'c:\\Users\\s1005\\OneDrive\\文件\\PLM_DOCS\\code\\githubs\\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation\\notebooks\\train_all'

# %%
# --- model factory (fresh per fold) ---
from src.models.wrappers.dpcn_concat_unet import DPCNConcatUNet
BASE_KW = {"cbam_reduction": 16}

def make_model(MODEL_NAME, train_loader = None) -> nn.Module:
    if MODEL_NAME == "MATHFI":
        # --- loss ---
        from src.training.loss_functions import DiceBCEComplementLoss

        def estimate_class_weights(loader, max_batches=20):
            with torch.no_grad():
                s = 0.0; n = 0
                for i, b in enumerate(loader):
                    s += b["mask"].float().mean().item(); n += 1
                    if i+1 >= max_batches: break
            p = max(1e-6, min(1-1e-6, s / max(1, n)))
            w1 = 1.0 / p; w0 = 1.0 / (1.0 - p)
            s2 = w0 + w1; w0 = 2.0 * w0 / s2; w1 = 2.0 * w1 / s2
            return w0, w1
        
        w0, w1 = estimate_class_weights(train_loader, max_batches=20)
        loss_fn = DiceBCEComplementLoss(w0=w0, w1=w1, dice_weight=0.5, bce_weight=0.5,
                                        exact_equation=False, reduction="mean")
        
        # --- model ---
        return DPCNConcatUNet(
            in_ch=1, enh_channels=64, iters=6,
            threshold_mode="scaled_vat", half_life=2.0,
            reduce_to=64, base_kwargs=BASE_KW
        ).to(DEVICE), loss_fn

    elif MODEL_NAME == "FR-UNet":
        loss_fn = nn.BCEWithLogitsLoss()
        from models.fr_unet import FR_UNet
        return FR_UNet().to(DEVICE), loss_fn
        
@torch.no_grad()
def sliding_window_forward_logits(model, img_1chw, window, overlap, device="cuda"):
    """
    img_1chw: torch.Tensor [1,1,H,W] on *any* device.
    Returns: averaged logits [1,1,H,W] on 'device'
    """
    model.eval()
    img = img_1chw.to(device, non_blocking=True)
    _, _, H, W = img.shape
    step = max(1, int(window * (1 - overlap)))

    # we'll average *logits* to keep your loss_fn (e.g., BCEWithLogits) unchanged
    acc  = torch.zeros_like(img, device=device)
    norm = torch.zeros_like(img, device=device)

    for y0 in range(0, max(1, H - window + 1), step):
        for x0 in range(0, max(1, W - window + 1), step):
            y1 = min(y0 + window, H); x1 = min(x0 + window, W)
            y0 = y1 - window;         x0 = x1 - window
            tile = img[:, :, y0:y1, x0:x1]                     # [1,1,win,win]
            with torch.amp.autocast(device_type="cuda", enabled=(device=="cuda")):
                logit = model(tile)                            # [1,1,win,win]
            acc[:, :, y0:y1, x0:x1] += logit
            norm[:, :, y0:y1, x0:x1] += 1.0

    logits = acc / torch.clamp_min(norm, 1.0)
    return logits

@torch.no_grad()
def infer_full_logits(model: nn.Module, img_1chw: torch.Tensor, device=DEVICE, window=VAL_WINDOW, overlap=VAL_OVERLAP):
    model.eval()
    return sliding_window_forward_logits(model, img_1chw, window=window, overlap=overlap, device=device)


def add_metrics(model_name, root, label_folder, img_size, ckpt_path, threshold_eval, all_metrics):
        
        model, _ = make_model(model_name)
        stem = Path(ckpt_path).stem  # "STARE_fold00"
        fold_id = int(stem.split("fold")[-1])  # 0
        #print(f"checkpoint_path: {ckpt_path}\nfold_id:{fold_id}")

        _, te_pairs = stare_loo_fold(root, label_folder=label_folder, fold_id=fold_id)
        
        _, test_loader = make_loaders(
            train_pairs=te_pairs, val_pairs=te_pairs,
            image_size=img_size, batch_size=1, num_workers=1,
            seed=SEED, strict_fov=True,
            augs_train=None, augs_val=get_val_augs(img_size),
        )
        model.load_state_dict(torch.load(ckpt_path, map_location=DEVICE))
        model.eval()

        batch = next(iter(test_loader))
        x   = batch["image"].to(DEVICE)
        y   = batch["mask"].to(DEVICE)
        fov = batch.get("fov", torch.ones_like(y)).to(DEVICE)
        img_path = batch["image_path"][0]
        img_stem = Path(img_path).stem

        logits = infer_full_logits(model, x, window=VAL_WINDOW, overlap=VAL_OVERLAP, device=DEVICE)
        prob   = torch.sigmoid(logits)
        # binm   = (prob >= threshold_eval).float()

        # 6a) metrics
        # 6a) metrics — use YOUR metrics module via our wrapper
        m = eval_leftout_with_fov(prob[0,0], y[0,0], fov[0,0], thr=threshold_eval)
        m["fold_id"]  = fold_id
        m["image_id"] = img_stem
        all_metrics.append(m)

        def _fmt(v):  # pretty-print, handles NaN
            try:
                return f"{v:.4f}" if v == v else "nan"
            except Exception:
                return str(v)

        print(
            f"== [F{fold_id:02d}] {img_stem} == \n"
            + "\n".join([f"{k}={_fmt(m[k])}" for k in ["SEN","SPE", "CLDICE", "ACC","Dice","IoU","AUC"]])
        )


# --- tiny metric collector (use yours if evaluate_and_print returns a dict) ---
from sklearn.metrics import roc_auc_score, average_precision_score


# --- DATASET HYPERPARAM SCHEDULERS ---
def sched_vessel_bias(epoch):
    if epoch <= 10: return 0.70
    if epoch <= 35: return 0.60
    return 0.50

def sched_min_percent_vessel(epoch):
    if epoch <= 10: return 0.008
    if epoch <= 35: return 0.010
    return 0.008

def sched_patch_size(epoch):
    return 160 if epoch > 45 else 128

# ---- single updater ----
def update_dataset(ds, epoch):
    ds.vessel_bias_p      = sched_vessel_bias(epoch)
    ds.min_percent_vessel = sched_min_percent_vessel(epoch)
    ds.patch_size         = sched_patch_size(epoch)

    
# --- training boilerplate (pass FOV into the model so DPCN can clamp each iter) ---
def train_one_epoch(model, loader, optimizer, scaler, loss_fn, device=DEVICE):
    model.train()
    total, n = 0.0, 0
    for batch in loader:
        x   = batch["image"].to(device, non_blocking=True)
        y   = batch["mask"].to(device,  non_blocking=True)
        fov = batch.get("fov", torch.ones_like(y)).to(device, non_blocking=True)

        # restrict labels to FOV (keeps loss fair)
        y = y * (fov > 0.5).float()

        optimizer.zero_grad(set_to_none=True)
        with torch.amp.autocast(device_type="cuda", enabled=(device=="cuda")):
            if model.uses_fov: logits = model(x, fov=fov)          # << pass FOV so DPCN uses it
            else: logits = model(x)
            loss   = loss_fn(logits, y)

        scaler.scale(loss).backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        scaler.step(optimizer); scaler.update()

        total += loss.item() * x.size(0); n += x.size(0)
    return total / max(1, n)

@torch.no_grad()
def validate_loss_only(model, loader, loss_fn,  window, overlap, device=DEVICE,):
    model.eval()
    total, n = 0.0, 0
    for batch in loader:
        x   = batch["image"].to(device, non_blocking=True)
        y   = batch["mask"].to(device,  non_blocking=True)
        fov = batch.get("fov", torch.ones_like(y)).to(device, non_blocking=True)

        for i in range(x.size(0)):
            logits_i = infer_full_logits(model, x[i:i+1], device=device, window=window, overlap=overlap)
            yi = y[i:i+1] * (fov[i:i+1] > 0.5).float()
            with torch.amp.autocast(device_type="cuda", enabled=(device=="cuda")):
                loss_i = loss_fn(logits_i, yi)
            total += loss_i.item(); n += 1
    return total / max(1, n)

def atomic_torch_save(state, path: Path):
    path = Path(path); tmp = path.with_suffix(path.suffix + ".partial")
    try: tmp.unlink()
    except FileNotFoundError: pass
    with open(tmp, "wb") as f:
        torch.save(state, f); f.flush(); os.fsync(f.fileno())
    os.replace(tmp, path)


def visualize_batch(loader, name="Loader", n_max=None):
    import matplotlib.pyplot as plt
    total_shown = 0
    for b_idx, batch in enumerate(loader):
        imgs = batch["image"]
        masks = batch["mask"]
        img_path = batch["image_path"][0]
        for i in range(imgs.size(0)):
            total_shown += 1
            if n_max and total_shown > n_max:
                print(f"\nStopped after showing {n_max} images.")
                return
            fig, axs = plt.subplots(1, 2, figsize=(6, 3))
            axs[0].imshow(imgs[i, 0].cpu(), cmap="gray")
            axs[0].set_title(f"{name} Image {total_shown} • {Path(img_path).name} ")
            axs[1].imshow(masks[i, 0].cpu(), cmap="gray")
            axs[1].set_title(f"{name} Mask {total_shown}")
            for ax in axs: ax.axis("off")
            plt.tight_layout()
            plt.show()

# %% [markdown]
# # MAIN RUN

# %%
splits, counts = chase_mc_balanced_splits(
    DATASET_ROOT, label_folder=DATASET_LABELFOLDER, n_runs=7
)
# Out:
# ['04', '03', '06', '09']
# ['05', '09', '04', '14']
# ['11', '02', '07', '10']
# ['02', '14', '08', '12']
# ['12', '05', '06', '09']
# ['12', '02', '04', '10']
# ['07', '02', '06', '03']
# {'01': 0, '02': 4, '03': 2, '04': 3, '05': 2, '06': 3, '07': 2, '08': 1, '09': 3, '10': 2, '11': 1, '12': 3, '13': 0, '14': 2}

# %%
# --- main LOO run ---
def run_chase_experiment(
    root=DATASET_ROOT, label_folder=DATASET_LABELFOLDER, epochs=EPOCHS, warmup=warmup_epochs, V_MULT=V_MULT,
    batch_size=BATCH_SIZE, img_size=IMG_SIZE, patch_train=True, patch_size=PATCH_SIZE, vessel_bias_p=VESSEL_BIAS,
    threshold_eval=THRESHOLD_EVAL, folds=FOLDS, fold_id=0, chckpnt_paths=None
):  
    rng = np.random.RandomState(SEED)
    all_metrics = []
    per_image_preds = {}   # img_stem -> dict(prob_path, bin_path, fold_id)
    
    while fold_id < folds:
        
        # add checkpoint paths to metric list
        if chckpnt_paths:
            for ckpt in chckpnt_paths:
                add_metrics(MODEL_NAME, 
                            DATASET_ROOT, 
                            DATASET_LABELFOLDER,
                            img_size, ckpt, 
                            threshold_eval, all_metrics) 
            chckpnt_paths.clear()

        print(f"\n========== {MODEL_NAME} {DATASET} NEW SPLIT, Fold {fold_id+1}/{folds} ==========")

        tr_pairs, te_pairs, _ = splits[fold_id]

        # 2) carve val deterministically from train
        val_pairs = tr_pairs[-4:]
        tr_pairs_ = tr_pairs[:-4]

        # 3) loaders
        train_loader, val_loader = make_loaders(
            train_pairs=tr_pairs_, val_pairs=val_pairs,
            image_size=IMG_SIZE, batch_size=BATCH_SIZE, num_workers=1,
            seed=SEED + fold_id, strict_fov=True,
            augs_train=get_train_augs(IMG_SIZE),
            augs_val=get_val_augs(IMG_SIZE),
            patch_train=True, patch_size=PATCH_SIZE,
            vessel_bias_p=VESSEL_BIAS, virtual_mult=V_MULT,
        )

        _, test_loader = make_loaders(
            train_pairs=te_pairs, val_pairs=te_pairs,
            image_size=IMG_SIZE, batch_size=1, num_workers=1,
            seed=SEED, strict_fov=True,
            augs_train=None, augs_val=get_val_augs(IMG_SIZE),
        )


        #visualize_batch(train_loader, "Train")
        #visualize_batch(test_loader, "Test")

        # 4) model & optimizer
        model, loss_fn = make_model(MODEL_NAME, train_loader)
        model.uses_fov = MODEL_NAME == "MATHFI"     # whether to pass fov in forward or not

    

        optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-4)
        scaler    = torch.amp.GradScaler("cuda", enabled=(DEVICE=="cuda"))
        def lr_lambda(e):
            if e < warmup: return (e+1)/max(1, warmup)
            progress = (e - warmup) / max(1, epochs - warmup)
            return 0.5 * (1 + math.cos(math.pi * progress))
        scheduler = LambdaLR(optimizer, lr_lambda)

        # 5) train with best-val checkpointing
        best_val = float("inf")
        ckpt_path = SAVE_CKPT / f"{DATASET}_fold{fold_id:02d}.pth"

        train_losses, val_losses = [], []

        for ep in range(1, epochs+1):
            update_dataset(train_loader.dataset, ep)
            t0=time.time()
            tr_loss  = train_one_epoch(model, train_loader, optimizer, scaler, loss_fn)
            val_loss = validate_loss_only(model, val_loader, loss_fn, PATCH_SIZE, VAL_OVERLAP)
            scheduler.step()
            print(f"[F{fold_id:02d} E{ep:03d}] train={tr_loss:.4f} val={val_loss:.4f} "
                  f"lr={optimizer.param_groups[0]['lr']:.2e} time={(time.time()-t0):.1f}s")
            
            
            train_losses.append(float(tr_loss))
            val_losses.append(float(val_loss))

            if val_loss < best_val:
                best_val = val_loss
                atomic_torch_save(model.state_dict(), ckpt_path)
                print(f"\tCHECKPOINT SAVED: {ckpt_path}")
        
        plt.figure(figsize=(6,3.5))
        plt.plot(range(1, len(train_losses)+1), train_losses, label="train")
        plt.plot(range(1, len(val_losses)+1),   val_losses,   label="val")
        plt.xlabel("epoch"); plt.ylabel("loss"); plt.grid(True); plt.legend()
        plt.title("Train vs Val Loss:" + TITLE)
        plt.tight_layout()
        plt.show()

        # 6) eval on left-out image using best checkpoint

        model.load_state_dict(torch.load(ckpt_path, map_location=DEVICE))
        model.eval()

        batch = next(iter(test_loader))
        x   = batch["image"].to(DEVICE)
        y   = batch["mask"].to(DEVICE)
        fov = batch.get("fov", torch.ones_like(y)).to(DEVICE)
        img_path = batch["image_path"][0]
        img_stem = Path(img_path).stem

        logits = infer_full_logits(model, x, window=VAL_WINDOW, overlap=VAL_OVERLAP, device=DEVICE)
        prob   = torch.sigmoid(logits)
        binm   = (prob >= threshold_eval).float()

        # 6a) metrics
        # 6a) metrics — use YOUR metrics module via our wrapper
        m = eval_leftout_with_fov(prob[0,0], y[0,0], fov[0,0], thr=threshold_eval)
        m["fold_id"]  = fold_id
        m["image_id"] = img_stem
        all_metrics.append(m)

        def _fmt(v):  # pretty-print, handles NaN
            try:
                return f"{v:.4f}" if v == v else "nan"
            except Exception:
                return str(v)

        print(
            f"== [F{fold_id:02d}] {img_stem} == \n"
            + "\n".join([f"{k}={_fmt(m[k])}" for k in ["SEN","SPE", "CLDICE", "ACC","Dice","IoU","AUC"]])
        )


        # 6b) save predictions
        SAVE_FILE = SAVE_PRED / f"{img_stem}__fold{fold_id:02d}.pt"
        torch.save({"logits": logits.cpu(), "prob": prob.cpu(), "bin": binm.cpu(),
                    "image_path": img_path, "fold": fold_id},
                  SAVE_FILE)
        per_image_preds[img_stem] = dict(
            prob_path=str((SAVE_PRED / f"{img_stem}__fold{fold_id:02d}.pt").as_posix()),
            fold_id=fold_id
        )

        print(f"== Predictions SAVED TO FILE: {SAVE_FILE} ==")

        # 6c) quick visualization panel for this test image
        fig, axs = plt.subplots(1,4, figsize=(12,3))
        axs[0].imshow(x[0,0].cpu(), cmap="gray"); axs[0].set_title("Image"); axs[0].axis("off")
        axs[1].imshow(y[0,0].cpu(), cmap="gray"); axs[1].set_title("GT");    axs[1].axis("off")
        axs[2].imshow(prob[0,0].cpu(), cmap="gray"); axs[2].set_title("Prob"); axs[2].axis("off")
        axs[3].imshow(binm[0,0].cpu(), cmap="gray"); axs[3].set_title(f"Pred@{threshold_eval}"); axs[3].axis("off")
        fig.suptitle(f"{DATASET} NEW SPLITS Fold {fold_id} — {img_stem}")
        plt.tight_layout(); plt.show(); fig.savefig(SAVE_VIZ / f"{img_stem}__fold{fold_id:02d}.png", dpi=150)
        plt.close(fig)

        fold_id = fold_id + 1

        # END OF FOLD LOOP
    


    # 7) aggregate & save CSV
    import csv
    keys = ["fold_id","image_id","SEN","SPE", "CLDICE", "ACC","Dice","IoU","AUC","AP"]
    csv_path = SAVE_LOGS / f"{DATASET}_newSplit_perfold.csv"
    with open(csv_path, "w", newline="") as f:
        w = csv.DictWriter(f, fieldnames=keys); w.writeheader()
        for row in all_metrics: w.writerow({k: row.get(k, "") for k in keys})

    # mean±std
    def _ms(name):
        arr = np.array([r[name] for r in all_metrics if not np.isnan(r[name])], dtype=float)
        return float(arr.mean()), float(arr.std(ddof=1)) if arr.size > 1 else 0.0
    summary = {k: _ms(k) for k in ["SEN","SPE","CLDICE","ACC","Dice","IoU","AUC","AP"]}
    print(f"\n=== {MODEL_NAME} {DATASET} NEW SPLITS ({FOLDS} folds) — mean ± std ===")
    for k,(mu,sig) in summary.items():
        print(f"{k}: {mu:.4f} ± {sig:.4f}")

    with open(SAVE_LOGS / f"{DATASET}_newSplit_summary.json","w") as f:
        json.dump({k: {"mean": mu, "std": sig} for k,(mu,sig) in summary.items()}, f, indent=2)

    # 8) (optional) gallery index of unbiased predictions
    with open(SAVE_LOGS / f"{DATASET}_newSplit_per_image_preds.json","w") as f:
        json.dump(per_image_preds, f, indent=2)

    return all_metrics, summary

# %%
# Check indiv chkpoint paths scores
"""
check_checkpoints = [
 "..\..\..\..\pth\FR-UNet_STARE_NEWSPLIT\checkpoints\STARE_fold00.pth",
]

for checkpoint in check_checkpoints:
    add_metrics(MODEL_NAME, 
                DATASET_ROOT, 
                DATASET_LABELFOLDER,
                IMG_SIZE, 
                checkpoint,
                THRESHOLD_EVAL, [])

"""
# Out:
# '\ncheck_checkpoints = [\n "..\\..\\..\\..\\pth\\FR-UNet_STARE_NEWSPLIT\\checkpoints\\STARE_fold00.pth",\n]\n\nfor checkpoint in check_checkpoints:\n    add_metrics(MODEL_NAME, \n                DATASET_ROOT, \n                DATASET_LABELFOLDER,\n                IMG_SIZE, \n                checkpoint,\n                THRESHOLD_EVAL, [])\n\n'

# %%
"""
path = r"..\..\..\..\pth\FR-UNet_STARE_NEWSPLIT\predictions\01_test__fold00.pt"
data = torch.load(path, map_location="cpu")

stem = Path(path).stem  # "STARE_fold00"
fold_id = int(stem.split("fold")[-1])  # 0

_, te_pairs = stare_loo_fold(DATASET_ROOT, label_folder=DATASET_LABELFOLDER, fold_id=fold_id)

_, test_loader = make_loaders(
    train_pairs=te_pairs, val_pairs=te_pairs,
    image_size=IMG_SIZE, batch_size=1, num_workers=1,
    seed=SEED, strict_fov=True,
    augs_train=None, augs_val=get_val_augs(IMG_SIZE),
)

batch = next(iter(test_loader))
x   = batch["image"].to(DEVICE)
y   = batch["mask"].to(DEVICE)
logits = data["logits"]   # raw model outputs before sigmoid
prob   = data["prob"]     # probability map (0–1)
binm   = data["bin"]      # binary mask (0 or 1)
img_path = data["image_path"]
fold_id = data["fold"]
img_stem = Path(batch["image_path"][0]).stem

fig, axs = plt.subplots(1,4, figsize=(12,3))
axs[0].imshow(x[0,0].cpu(), cmap="gray"); axs[0].set_title("Image"); axs[0].axis("off")
axs[1].imshow(y[0,0].cpu(), cmap="gray"); axs[1].set_title("GT");    axs[1].axis("off")
axs[2].imshow(prob[0,0].cpu(), cmap="gray"); axs[2].set_title("Prob"); axs[2].axis("off")
axs[3].imshow(binm[0,0].cpu(), cmap="gray"); axs[3].set_title(f"Pred@0.5"); axs[3].axis("off")
fig.suptitle(f"{DATASET} NEW SPLITS Fold {fold_id} — {img_stem}")
plt.tight_layout(); plt.show()

"""
# Out:
# '\npath = r"..\\..\\..\\..\\pth\\FR-UNet_STARE_NEWSPLIT\\predictions\x01_test__fold00.pt"\ndata = torch.load(path, map_location="cpu")\n\nstem = Path(path).stem  # "STARE_fold00"\nfold_id = int(stem.split("fold")[-1])  # 0\n\n_, te_pairs = stare_loo_fold(DATASET_ROOT, label_folder=DATASET_LABELFOLDER, fold_id=fold_id)\n\n_, test_loader = make_loaders(\n    train_pairs=te_pairs, val_pairs=te_pairs,\n    image_size=IMG_SIZE, batch_size=1, num_workers=1,\n    seed=SEED, strict_fov=True,\n    augs_train=None, augs_val=get_val_augs(IMG_SIZE),\n)\n\nbatch = next(iter(test_loader))\nx   = batch["image"].to(DEVICE)\ny   = batch["mask"].to(DEVICE)\nlogits = data["logits"]   # raw model outputs before sigmoid\nprob   = data["prob"]     # probability map (0–1)\nbinm   = data["bin"]      # binary mask (0 or 1)\nimg_path = data["image_path"]\nfold_id = data["fold"]\nimg_stem = Path(batch["image_path"][0]).stem\n\nfig, axs = plt.subplots(1,4, figsize=(12,3))\naxs[0].imshow(x[0,0].cpu(), cmap="gray"); axs[0].set_title("Image"); axs[0].axis("off")\naxs[1].imshow(y[0,0].cpu(), cmap="gray"); axs[1].set_title("GT");    axs[1].axis("off")\naxs[2].imshow(prob[0,0].cpu(), cmap="gray"); axs[2].set_title("Prob"); axs[2].axis("off")\naxs[3].imshow(binm[0,0].cpu(), cmap="gray"); axs[3].set_title(f"Pred@0.5"); axs[3].axis("off")\nfig.suptitle(f"{DATASET} NEW SPLITS Fold {fold_id} — {img_stem}")\nplt.tight_layout(); plt.show()\n\n'

# %%
all_metrics, summary = run_chase_experiment(
    root=DATASET_ROOT,
    label_folder=DATASET_LABELFOLDER,
    epochs=EPOCHS,
    warmup=warmup_epochs,
    batch_size=BATCH_SIZE,
    img_size=IMG_SIZE,
    patch_train=True,
    patch_size=PATCH_SIZE,
    vessel_bias_p=VESSEL_BIAS,
    threshold_eval=THRESHOLD_EVAL,
    folds=FOLDS,
    fold_id=FOLD_ID,   #starts at any fold_id

    chckpnt_paths= [
        "..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth",
        "..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth",
         "..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth"

    ]
)
# Out:
# ========== FR-UNet CHASEDB1 NEW SPLIT, Fold 1/5 ==========
# c:\Users\s1005\OneDrive\文件\PLM_DOCS\code\githubs\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation\venv310\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# [F00 E001] train=0.6331 val=0.4691 lr=1.20e-04 time=12.7s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E002] train=0.5034 val=0.3362 lr=1.80e-04 time=12.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E003] train=0.3790 val=0.2493 lr=2.40e-04 time=11.7s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E004] train=0.2788 val=0.1737 lr=3.00e-04 time=15.3s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E005] train=0.2144 val=0.1247 lr=3.00e-04 time=12.5s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E006] train=0.1780 val=0.1001 lr=3.00e-04 time=11.8s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E007] train=0.1639 val=0.0998 lr=2.99e-04 time=11.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E008] train=0.1573 val=0.0851 lr=2.97e-04 time=11.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E009] train=0.1500 val=0.0810 lr=2.94e-04 time=19.3s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E010] train=0.1402 val=0.0806 lr=2.91e-04 time=19.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E011] train=0.1360 val=0.0767 lr=2.87e-04 time=19.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E012] train=0.1338 val=0.0775 lr=2.82e-04 time=19.7s
# [F00 E013] train=0.1348 val=0.0755 lr=2.77e-04 time=20.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E014] train=0.1326 val=0.0749 lr=2.71e-04 time=19.8s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E015] train=0.1332 val=0.0718 lr=2.65e-04 time=20.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E016] train=0.1292 val=0.0750 lr=2.58e-04 time=20.4s
# [F00 E017] train=0.1253 val=0.0705 lr=2.50e-04 time=20.4s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E018] train=0.1219 val=0.0703 lr=2.42e-04 time=20.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E019] train=0.1191 val=0.0675 lr=2.34e-04 time=19.7s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E020] train=0.1188 val=0.0683 lr=2.25e-04 time=20.3s
# [F00 E021] train=0.1215 val=0.0699 lr=2.16e-04 time=20.3s
# [F00 E022] train=0.1222 val=0.0665 lr=2.06e-04 time=20.1s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E023] train=0.1177 val=0.0672 lr=1.96e-04 time=20.0s
# [F00 E024] train=0.1184 val=0.0661 lr=1.86e-04 time=20.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E025] train=0.1185 val=0.0664 lr=1.76e-04 time=20.3s
# [F00 E026] train=0.1133 val=0.0665 lr=1.66e-04 time=20.4s
# [F00 E027] train=0.1140 val=0.0664 lr=1.55e-04 time=20.0s
# [F00 E028] train=0.1131 val=0.0670 lr=1.45e-04 time=19.9s
# [F00 E029] train=0.1169 val=0.0661 lr=1.34e-04 time=19.8s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E030] train=0.1162 val=0.0655 lr=1.24e-04 time=20.1s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E031] train=0.1158 val=0.0657 lr=1.14e-04 time=19.9s
# [F00 E032] train=0.1167 val=0.0647 lr=1.04e-04 time=20.3s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E033] train=0.1161 val=0.0671 lr=9.38e-05 time=15.7s
# [F00 E034] train=0.1169 val=0.0657 lr=8.42e-05 time=12.0s
# [F00 E035] train=0.1132 val=0.0658 lr=7.50e-05 time=11.8s
# [F00 E036] train=0.1100 val=0.0639 lr=6.61e-05 time=12.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E037] train=0.1138 val=0.0641 lr=5.77e-05 time=12.0s
# [F00 E038] train=0.1089 val=0.0651 lr=4.96e-05 time=11.9s
# [F00 E039] train=0.1144 val=0.0648 lr=4.21e-05 time=11.8s
# [F00 E040] train=0.1120 val=0.0634 lr=3.51e-05 time=11.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E041] train=0.1139 val=0.0647 lr=2.86e-05 time=12.0s
# [F00 E042] train=0.1089 val=0.0625 lr=2.28e-05 time=12.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E043] train=0.1081 val=0.0630 lr=1.76e-05 time=11.8s
# [F00 E044] train=0.1090 val=0.0623 lr=1.30e-05 time=14.6s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E045] train=0.1099 val=0.0632 lr=9.05e-06 time=20.2s
# [F00 E046] train=0.1057 val=0.0634 lr=5.81e-06 time=19.8s
# [F00 E047] train=0.1038 val=0.0621 lr=3.28e-06 time=19.4s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E048] train=0.1064 val=0.0625 lr=1.46e-06 time=19.4s
# [F00 E049] train=0.1034 val=0.0625 lr=3.65e-07 time=19.5s
# [F00 E050] train=0.1060 val=0.0644 lr=0.00e+00 time=19.3s
# == [F00] 07_test ==
# SEN=0.8889
# SPE=0.9844
# CLDICE=0.8392
# ACC=0.9795
# Dice=0.8170
# IoU=0.6906
# AUC=0.9928
# == Predictions SAVED TO FILE: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\predictions\07_test__fold00.pt ==
# ========== FR-UNet CHASEDB1 NEW SPLIT, Fold 2/5 ==========
# [F01 E001] train=0.6394 val=0.4519 lr=1.20e-04 time=19.6s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E002] train=0.4852 val=0.3385 lr=1.80e-04 time=19.4s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E003] train=0.3685 val=0.2407 lr=2.40e-04 time=19.3s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E004] train=0.2775 val=0.1666 lr=3.00e-04 time=19.7s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E005] train=0.2181 val=0.1213 lr=3.00e-04 time=19.6s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E006] train=0.1926 val=0.1028 lr=3.00e-04 time=19.4s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E007] train=0.1640 val=0.0924 lr=2.99e-04 time=18.7s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E008] train=0.1555 val=0.0853 lr=2.97e-04 time=19.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E009] train=0.1507 val=0.0802 lr=2.94e-04 time=19.2s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E010] train=0.1427 val=0.0800 lr=2.91e-04 time=19.3s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E011] train=0.1375 val=0.0798 lr=2.87e-04 time=19.1s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E012] train=0.1387 val=0.0734 lr=2.82e-04 time=19.2s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E013] train=0.1345 val=0.0748 lr=2.77e-04 time=18.2s
# [F01 E014] train=0.1307 val=0.0745 lr=2.71e-04 time=11.8s
# [F01 E015] train=0.1319 val=0.0687 lr=2.65e-04 time=11.7s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E016] train=0.1232 val=0.0693 lr=2.58e-04 time=11.9s
# [F01 E017] train=0.1238 val=0.0707 lr=2.50e-04 time=11.7s
# [F01 E018] train=0.1252 val=0.0679 lr=2.42e-04 time=11.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E019] train=0.1222 val=0.0682 lr=2.34e-04 time=11.9s
# [F01 E020] train=0.1158 val=0.0661 lr=2.25e-04 time=16.1s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E021] train=0.1208 val=0.0651 lr=2.16e-04 time=18.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E022] train=0.1162 val=0.0670 lr=2.06e-04 time=14.6s
# [F01 E023] train=0.1176 val=0.0637 lr=1.96e-04 time=12.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E024] train=0.1170 val=0.0642 lr=1.86e-04 time=11.9s
# [F01 E025] train=0.1131 val=0.0633 lr=1.76e-04 time=18.8s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E026] train=0.1167 val=0.0631 lr=1.66e-04 time=20.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E027] train=0.1130 val=0.0636 lr=1.55e-04 time=19.1s
# [F01 E028] train=0.1105 val=0.0621 lr=1.45e-04 time=12.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E029] train=0.1138 val=0.0631 lr=1.34e-04 time=12.1s
# [F01 E030] train=0.1115 val=0.0624 lr=1.24e-04 time=12.0s
# [F01 E031] train=0.1089 val=0.0623 lr=1.14e-04 time=13.3s
# [F01 E032] train=0.1123 val=0.0629 lr=1.04e-04 time=12.8s
# [F01 E033] train=0.1110 val=0.0627 lr=9.38e-05 time=13.6s
# [F01 E034] train=0.1122 val=0.0623 lr=8.42e-05 time=11.9s
# [F01 E035] train=0.1082 val=0.0637 lr=7.50e-05 time=14.8s
# [F01 E036] train=0.1107 val=0.0620 lr=6.61e-05 time=11.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E037] train=0.1105 val=0.0616 lr=5.77e-05 time=11.8s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E038] train=0.1074 val=0.0628 lr=4.96e-05 time=12.3s
# [F01 E039] train=0.1042 val=0.0624 lr=4.21e-05 time=11.9s
# [F01 E040] train=0.1122 val=0.0625 lr=3.51e-05 time=12.0s
# [F01 E041] train=0.1083 val=0.0618 lr=2.86e-05 time=14.9s
# [F01 E042] train=0.1084 val=0.0608 lr=2.28e-05 time=18.6s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E043] train=0.1039 val=0.0609 lr=1.76e-05 time=17.7s
# [F01 E044] train=0.1076 val=0.0616 lr=1.30e-05 time=18.0s
# [F01 E045] train=0.1040 val=0.0604 lr=9.05e-06 time=17.2s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E046] train=0.1036 val=0.0613 lr=5.81e-06 time=18.6s
# [F01 E047] train=0.1046 val=0.0607 lr=3.28e-06 time=20.5s
# [F01 E048] train=0.1035 val=0.0610 lr=1.46e-06 time=20.4s
# [F01 E049] train=0.1023 val=0.0608 lr=3.65e-07 time=20.2s
# [F01 E050] train=0.1044 val=0.0612 lr=0.00e+00 time=20.2s
# == [F01] 09_test ==
# SEN=0.8204
# SPE=0.9821
# CLDICE=0.8247
# ACC=0.9709
# Dice=0.7961
# IoU=0.6613
# AUC=0.9874
# == Predictions SAVED TO FILE: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\predictions\09_test__fold01.pt ==
# ========== FR-UNet CHASEDB1 NEW SPLIT, Fold 3/5 ==========
# [F02 E001] train=0.6144 val=0.4434 lr=1.20e-04 time=20.3s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E002] train=0.4671 val=0.3396 lr=1.80e-04 time=20.3s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E003] train=0.3556 val=0.2316 lr=2.40e-04 time=20.3s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E004] train=0.2635 val=0.1638 lr=3.00e-04 time=20.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E005] train=0.2097 val=0.1270 lr=3.00e-04 time=20.1s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E006] train=0.1759 val=0.1014 lr=3.00e-04 time=19.8s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E007] train=0.1640 val=0.0941 lr=2.99e-04 time=19.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E008] train=0.1486 val=0.0825 lr=2.97e-04 time=19.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E009] train=0.1471 val=0.0772 lr=2.94e-04 time=20.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E010] train=0.1409 val=0.0769 lr=2.91e-04 time=19.7s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E011] train=0.1348 val=0.0729 lr=2.87e-04 time=20.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E012] train=0.1349 val=0.0755 lr=2.82e-04 time=20.0s
# [F02 E013] train=0.1338 val=0.0726 lr=2.77e-04 time=17.7s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E014] train=0.1292 val=0.0723 lr=2.71e-04 time=15.3s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E015] train=0.1310 val=0.0712 lr=2.65e-04 time=12.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E016] train=0.1255 val=0.0707 lr=2.58e-04 time=11.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E017] train=0.1276 val=0.0679 lr=2.50e-04 time=11.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E018] train=0.1213 val=0.0697 lr=2.42e-04 time=17.4s
# [F02 E019] train=0.1225 val=0.0694 lr=2.34e-04 time=12.1s
# [F02 E020] train=0.1223 val=0.0678 lr=2.25e-04 time=11.8s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E021] train=0.1196 val=0.0660 lr=2.16e-04 time=11.7s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E022] train=0.1205 val=0.0646 lr=2.06e-04 time=11.8s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E023] train=0.1189 val=0.0665 lr=1.96e-04 time=11.7s
# [F02 E024] train=0.1208 val=0.0663 lr=1.86e-04 time=11.7s
# [F02 E025] train=0.1190 val=0.0666 lr=1.76e-04 time=11.6s
# [F02 E026] train=0.1186 val=0.0644 lr=1.66e-04 time=11.7s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E027] train=0.1176 val=0.0655 lr=1.55e-04 time=12.0s
# [F02 E028] train=0.1150 val=0.0658 lr=1.45e-04 time=12.0s
# [F02 E029] train=0.1174 val=0.0663 lr=1.34e-04 time=12.0s
# [F02 E030] train=0.1156 val=0.0668 lr=1.24e-04 time=11.8s
# [F02 E031] train=0.1162 val=0.0639 lr=1.14e-04 time=11.8s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E032] train=0.1119 val=0.0658 lr=1.04e-04 time=11.8s
# [F02 E033] train=0.1146 val=0.0645 lr=9.38e-05 time=12.9s
# [F02 E034] train=0.1137 val=0.0638 lr=8.42e-05 time=19.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E035] train=0.1134 val=0.0632 lr=7.50e-05 time=19.8s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E036] train=0.1096 val=0.0639 lr=6.61e-05 time=19.8s
# [F02 E037] train=0.1125 val=0.0631 lr=5.77e-05 time=19.7s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E038] train=0.1117 val=0.0638 lr=4.96e-05 time=19.6s
# [F02 E039] train=0.1139 val=0.0637 lr=4.21e-05 time=20.1s
# [F02 E040] train=0.1125 val=0.0637 lr=3.51e-05 time=19.5s
# [F02 E041] train=0.1131 val=0.0632 lr=2.86e-05 time=19.5s
# [F02 E042] train=0.1107 val=0.0633 lr=2.28e-05 time=12.4s
# [F02 E043] train=0.1099 val=0.0626 lr=1.76e-05 time=12.1s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E044] train=0.1112 val=0.0620 lr=1.30e-05 time=12.2s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E045] train=0.1115 val=0.0623 lr=9.05e-06 time=12.1s
# [F02 E046] train=0.1074 val=0.0623 lr=5.81e-06 time=11.8s
# [F02 E047] train=0.1078 val=0.0632 lr=3.28e-06 time=11.9s
# [F02 E048] train=0.1065 val=0.0626 lr=1.46e-06 time=12.1s
# [F02 E049] train=0.1073 val=0.0627 lr=3.65e-07 time=12.1s
# [F02 E050] train=0.1121 val=0.0624 lr=0.00e+00 time=11.8s
# == [F02] 21_training ==
# SEN=0.8173
# SPE=0.9914
# CLDICE=0.8772
# ACC=0.9784
# Dice=0.8503
# IoU=0.7396
# AUC=0.9920
# == Predictions SAVED TO FILE: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\predictions\21_training__fold02.pt ==
# ========== FR-UNet CHASEDB1 NEW SPLIT, Fold 4/5 ==========
# [F03 E001] train=0.5808 val=0.4103 lr=1.20e-04 time=12.1s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold03.pth
# [F03 E002] train=0.4382 val=0.2934 lr=1.80e-04 time=12.3s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold03.pth
# [F03 E003] train=0.3322 val=0.2034 lr=2.40e-04 time=12.1s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold03.pth
# [F03 E004] train=0.2485 val=0.1450 lr=3.00e-04 time=11.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\FR-UNet_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold03.pth
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 all_metrics, summary = run_chase_experiment(
#       2     root=DATASET_ROOT,
#       3     label_folder=DATASET_LABELFOLDER,
#       4     epochs=EPOCHS,
#       5     warmup=warmup_epochs,
#       6     batch_size=BATCH_SIZE,
#       7     img_size=IMG_SIZE,
#       8     patch_train=True,
#       9     patch_size=PATCH_SIZE,
#      10     vessel_bias_p=VESSEL_BIAS,
#      11     threshold_eval=THRESHOLD_EVAL,
#      12     folds=FOLDS,
#      13     fold_id=FOLD_ID,   #starts at any fold_id
#      14
#      15     chckpnt_paths= [
#      16          #"..\..\..\..\pth\FR-UNet_STARE_NEWSPLIT\checkpoints\STARE_fold00.pth",
#      17          #"..\..\..\..\pth\FR-UNet_STARE_NEWSPLIT\checkpoints\STARE_fold01.pth",
#      18          #"..\..\..\..\pth\FR-UNet_STARE_NEWSPLIT\checkpoints\STARE_fold02.pth"
#      19
#      20     ]
#      21 )
#
# Cell In[10], line 76, in run_chase_experiment(root, label_folder, epochs, warmup, V_MULT, batch_size, img_size, patch_train, patch_size, vessel_bias_p, threshold_eval, folds, fold_id, chckpnt_paths)
#      74 update_dataset(train_loader.dataset, ep)
#      75 t0=time.time()
# ---> 76 tr_loss  = train_one_epoch(model, train_loader, optimizer, scaler, loss_fn)
#      77 val_loss = validate_loss_only(model, val_loader, loss_fn, PATCH_SIZE, VAL_OVERLAP)
#      78 scheduler.step()
#
# Cell In[8], line 148, in train_one_epoch(model, loader, optimizer, scaler, loss_fn, device)
#     146 model.train()
#     147 total, n = 0.0, 0
# --> 148 for batch in loader:
#     149     x   = batch["image"].to(device, non_blocking=True)
#     150     y   = batch["mask"].to(device,  non_blocking=True)
#
# File c:\Users\s1005\OneDrive\文件\PLM_DOCS\code\githubs\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation\venv310\lib\site-packages\torch\utils\data\dataloader.py:734, in _BaseDataLoaderIter.__next__(self)
#     731 if self._sampler_iter is None:
#     732     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733     self._reset()  # type: ignore[call-arg]
# --> 734 data = self._next_data()
#     735 self._num_yielded += 1
#     736 if (
#     737     self._dataset_kind == _DatasetKind.Iterable
#     738     and self._IterableDataset_len_called is not None
#     739     and self._num_yielded > self._IterableDataset_len_called
#     740 ):
#
# File c:\Users\s1005\OneDrive\文件\PLM_DOCS\code\githubs\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation\venv310\lib\site-packages\torch\utils\data\dataloader.py:1492, in _MultiProcessingDataLoaderIter._next_data(self)
#    1489     return self._process_data(data, worker_id)
#    1491 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1492 idx, data = self._get_data()
#    1493 self._tasks_outstanding -= 1
#    1494 if self._dataset_kind == _DatasetKind.Iterable:
#    1495     # Check for _IterableDatasetStopIteration
#
# File c:\Users\s1005\OneDrive\文件\PLM_DOCS\code\githubs\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation\venv310\lib\site-packages\torch\utils\data\dataloader.py:1444, in _MultiProcessingDataLoaderIter._get_data(self)
#    1442 elif self._pin_memory:
#    1443     while self._pin_memory_thread.is_alive():
# -> 1444         success, data = self._try_get_data()
#    1445         if success:
#    1446             return data
#
# File c:\Users\s1005\OneDrive\文件\PLM_DOCS\code\githubs\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation\venv310\lib\site-packages\torch\utils\data\dataloader.py:1285, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1272 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1273     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1274     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1282     # Returns a 2-tuple:
#    1283     #   (bool: whether successfully get data, any: data if successful else None)
#    1284     try:
# -> 1285         data = self._data_queue.get(timeout=timeout)
#    1286         return (True, data)
#    1287     except Exception as e:
#    1288         # At timeout and error, we manually check whether any worker has
#    1289         # failed. Note that this is the only mechanism for Windows to detect
#    1290         # worker failures.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\queue.py:180, in Queue.get(self, block, timeout)
#     178         if remaining <= 0.0:
#     179             raise Empty
# --> 180         self.not_empty.wait(remaining)
#     181 item = self._get()
#     182 self.not_full.notify()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
