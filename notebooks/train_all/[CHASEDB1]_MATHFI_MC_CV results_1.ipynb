# %% [markdown]
# # [CHASEDB1] FRU-Net -- AGG FOLD LOOPS -- seed 1337

# %%
import sys, os
sys.path.append(os.path.abspath('../../'))
sys.path.append(os.path.abspath('../../../FR-UNet/'))

print( os.getcwd())
sys.path
# Out:
# c:\Users\s1005\OneDrive\文件\PLM_DOCS\code\githubs\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation\notebooks\train_all
# ['C:\\Users\\s1005\\AppData\\Local\\Programs\\Python\\Python310\\python310.zip',
#  'C:\\Users\\s1005\\AppData\\Local\\Programs\\Python\\Python310\\DLLs',
#  'C:\\Users\\s1005\\AppData\\Local\\Programs\\Python\\Python310\\lib',
#  'C:\\Users\\s1005\\AppData\\Local\\Programs\\Python\\Python310',
#  'c:\\Users\\s1005\\OneDrive\\文件\\PLM_DOCS\\code\\githubs\\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation\\venv310',
#  '',
#  'c:\\Users\\s1005\\OneDrive\\文件\\PLM_DOCS\\code\\githubs\\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation\\venv310\\lib\\site-packages',
#  'c:\\Users\\s1005\\OneDrive\\文件\\PLM_DOCS\\code\\githubs\\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation',
#  'c:\\Users\\s1005\\OneDrive\\文件\\PLM_DOCS\\code\\githubs\\FR-UNet']

# %%
from src.models.unet import UNet
print(UNet)
# Out:
# <class 'src.models.unet.UNet'>

# %%
from pathlib import Path
import torch
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# # CHANGE THESE

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
SEED   = 1337
DATASET = "CHASEDB1" # "DRIVE" | "STARE" | "CHASEDB1"

PATCH_SIZE = 128
VAL_WINDOW  = PATCH_SIZE
VAL_OVERLAP = 0.25

VESSEL_BIAS=0.7
MIN_PERCENT_VESSEL=0.008
V_MULT=30
DENSE_BIAS=None
BATCH_SIZE=2

IMG_SIZE=512

EPOCHS = 50
warmup_epochs = 5

FOLDS = 1
FOLD_ID = 0

THRESHOLD_EVAL = 0.5


MODEL_NAME = "MATHFI"
TITLE     = f"[{DATASET}] {MODEL_NAME} NEW SPLIT ({FOLDS} folds) -- seed 1337 -- DPCN 6x64 hl=2 reduce=64 cbam=16 epochs={EPOCHS}"
SAVE_ROOT = Path(f"../../../../pth/{MODEL_NAME}_{DATASET}_NEWSPLIT")     # a clean experiment folder
SAVE_CKPT = SAVE_ROOT / "checkpoints"
SAVE_PRED = SAVE_ROOT / "predictions"   # per-image logits/prob/masks
SAVE_VIZ  = SAVE_ROOT / "visuals"       # PNG overlays per test image
SAVE_LOGS = SAVE_ROOT / "logs"
for d in [SAVE_ROOT, SAVE_CKPT, SAVE_PRED, SAVE_VIZ, SAVE_LOGS]: d.mkdir(parents=True, exist_ok=True)

DATASET_ROOT        = f"../../../../Retinal_Vessel_Segmentation_Datasets/{DATASET}/"
DATASET_LABELFOLDER = "1st_manual"

# %% [markdown]
# # IMPORTS

# %%
import os, json, math, time, random
from pathlib import Path
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import LambdaLR
import matplotlib.pyplot as plt

# --- data utils ---
from src.data.splits import (
    split_drive_20_20,
    split_chase_subjectwise_20_8,
    split_stare_leave_one_out,
    stare_loo_fold,
    chase_mc_balanced_splits,
    drive_random_20_20,

    chase_random_subject_split,

)

from src.data.dataloader import make_loaders
from src.data.augmentations import get_train_augs, get_val_augs

# use YOUR metrics utilities
from src.training.metrics import (
    confusion_counts,
    dice as dice_metric,
    iou as iou_metric,
    roc_auc as roc_auc_metric,
    pr_auc as pr_auc_metric,
    acc_from_counts,
    recall_from_counts,          # sensitivity
    specificity_from_counts,     # specificity
    cldice
)



# --- evaluation & visualization ---
from src.evaluation.evaluate import evaluate_and_print
from src.evaluation.visualization import visualize_samples

# %% [markdown]
# # helpers and config

# %%
os.getcwd()
# Out:
# 'c:\\Users\\s1005\\OneDrive\\文件\\PLM_DOCS\\code\\githubs\\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation\\notebooks\\train_all'

# %%
splits, counts = chase_mc_balanced_splits(
    DATASET_ROOT, label_folder=DATASET_LABELFOLDER, n_runs=7
)
# Out:
# ['04', '03', '06', '09']
# ['05', '09', '04', '14']
# ['11', '02', '07', '10']
# ['02', '14', '08', '12']
# ['12', '05', '06', '09']
# ['12', '02', '04', '10']
# ['07', '02', '06', '03']
# {'01': 0, '02': 4, '03': 2, '04': 3, '05': 2, '06': 3, '07': 2, '08': 1, '09': 3, '10': 2, '11': 1, '12': 3, '13': 0, '14': 2}

# %%
# --- model factory (fresh per fold) ---
from src.models.wrappers.dpcn_concat_unet import DPCNConcatUNet
BASE_KW = {"cbam_reduction": 16}

def make_model(MODEL_NAME, train_loader = None) -> nn.Module:
    if MODEL_NAME == "MATHFI":
        # --- loss ---
        from src.training.loss_functions import DiceBCEComplementLoss

        def estimate_class_weights(loader, max_batches=20):
            with torch.no_grad():
                s = 0.0; n = 0
                for i, b in enumerate(loader):
                    s += b["mask"].float().mean().item(); n += 1
                    if i+1 >= max_batches: break
            p = max(1e-6, min(1-1e-6, s / max(1, n)))
            w1 = 1.0 / p; w0 = 1.0 / (1.0 - p)
            s2 = w0 + w1; w0 = 2.0 * w0 / s2; w1 = 2.0 * w1 / s2
            return w0, w1
        
        w0, w1 = estimate_class_weights(train_loader, max_batches=20)
        loss_fn = DiceBCEComplementLoss(w0=w0, w1=w1, dice_weight=0.5, bce_weight=0.5,
                                        exact_equation=False, reduction="mean")
        
        # --- model ---
        return DPCNConcatUNet(
            in_ch=1, enh_channels=64, iters=6,
            threshold_mode="scaled_vat", half_life=2.0,
            reduce_to=64, base_kwargs=BASE_KW
        ).to(DEVICE), loss_fn

    elif MODEL_NAME == "FR-UNet":
        loss_fn = nn.BCEWithLogitsLoss()
        from models.fr_unet import FR_UNet
        return FR_UNet().to(DEVICE), loss_fn
        
@torch.no_grad()
def sliding_window_forward_logits(model, img_1chw, window, overlap, device="cuda"):
    """
    img_1chw: torch.Tensor [1,1,H,W] on *any* device.
    Returns: averaged logits [1,1,H,W] on 'device'
    """
    model.eval()
    img = img_1chw.to(device, non_blocking=True)
    _, _, H, W = img.shape
    step = max(1, int(window * (1 - overlap)))

    # we'll average *logits* to keep your loss_fn (e.g., BCEWithLogits) unchanged
    acc  = torch.zeros_like(img, device=device)
    norm = torch.zeros_like(img, device=device)

    for y0 in range(0, max(1, H - window + 1), step):
        for x0 in range(0, max(1, W - window + 1), step):
            y1 = min(y0 + window, H); x1 = min(x0 + window, W)
            y0 = y1 - window;         x0 = x1 - window
            tile = img[:, :, y0:y1, x0:x1]                     # [1,1,win,win]
            with torch.amp.autocast(device_type="cuda", enabled=(device=="cuda")):
                logit = model(tile)                            # [1,1,win,win]
            acc[:, :, y0:y1, x0:x1] += logit
            norm[:, :, y0:y1, x0:x1] += 1.0

    logits = acc / torch.clamp_min(norm, 1.0)
    return logits

@torch.no_grad()
def infer_full_logits(model: nn.Module, img_1chw: torch.Tensor, device=DEVICE, window=VAL_WINDOW, overlap=VAL_OVERLAP):
    model.eval()
    return sliding_window_forward_logits(model, img_1chw, window=window, overlap=overlap, device=device)


def add_metrics(model_name, root, label_folder, img_size, ckpt_path, threshold_eval, all_metrics):
        
        model, _ = make_model(model_name)
        stem = Path(ckpt_path).stem  # "STARE_fold00"
        fold_id = int(stem.split("fold")[-1])  # 0
        #print(f"checkpoint_path: {ckpt_path}\nfold_id:{fold_id}")

        _, te_pairs, _ = splits[fold_id]


        _, test_loader = make_loaders(
            train_pairs=te_pairs, val_pairs=te_pairs,
            image_size=IMG_SIZE, batch_size=1, num_workers=1,
            seed=SEED, strict_fov=True,
            augs_train=None, augs_val=get_val_augs(IMG_SIZE),
        )
        
        model.load_state_dict(torch.load(ckpt_path, map_location=DEVICE))
        model.eval()

        #batch = next(iter(test_loader))
        #x   = batch["image"].to(DEVICE)
        #y   = batch["mask"].to(DEVICE)
        #fov = batch.get("fov", torch.ones_like(y)).to(DEVICE)
        img_stem = f"fold{fold_id:02d}_testset"

        #logits = infer_full_logits(model, x, window=VAL_WINDOW, overlap=VAL_OVERLAP, device=DEVICE)
        #prob   = torch.sigmoid(logits)
        # binm   = (prob >= threshold_eval).float()

        print(
            f"\n== [F{fold_id:02d}] {img_stem} == \n")
        #    + "\n".join([f"{k}={_fmt(m[k])}" for k in ["SEN","SPE", "CLDICE", "ACC","Dice","IoU","AUC"]])
        #)
        
        # 6a) metrics
        # 6a) metrics — use YOUR metrics module via our wrapper
        m = evaluate_and_print(model, test_loader, device = DEVICE, threshold=threshold_eval, compute_auc=True)
        m["fold_id"]  = fold_id
        m["image_id"] = img_stem
        all_metrics.append(m)

        def _fmt(v):  # pretty-print, handles NaN
            try:
                return f"{v:.4f}" if v == v else "nan"
            except Exception:
                return str(v)

        


# --- tiny metric collector (use yours if evaluate_and_print returns a dict) ---
from sklearn.metrics import roc_auc_score, average_precision_score


# --- DATASET HYPERPARAM SCHEDULERS ---
def sched_vessel_bias(epoch):
    if epoch <= 10: return 0.70
    if epoch <= 35: return 0.60
    return 0.50

def sched_min_percent_vessel(epoch):
    if epoch <= 10: return 0.008
    if epoch <= 35: return 0.010
    return 0.008

def sched_patch_size(epoch):
    return 160 if epoch > 45 else 128

# ---- single updater ----
def update_dataset(ds, epoch):
    ds.vessel_bias_p      = sched_vessel_bias(epoch)
    ds.min_percent_vessel = sched_min_percent_vessel(epoch)
    ds.patch_size         = sched_patch_size(epoch)

    
# --- training boilerplate (pass FOV into the model so DPCN can clamp each iter) ---
def train_one_epoch(model, loader, optimizer, scaler, loss_fn, device=DEVICE):
    model.train()
    total, n = 0.0, 0
    for batch in loader:
        x   = batch["image"].to(device, non_blocking=True)
        y   = batch["mask"].to(device,  non_blocking=True)
        fov = batch.get("fov", torch.ones_like(y)).to(device, non_blocking=True)

        # restrict labels to FOV (keeps loss fair)
        y = y * (fov > 0.5).float()

        optimizer.zero_grad(set_to_none=True)
        with torch.amp.autocast(device_type="cuda", enabled=(device=="cuda")):
            logits = model(x, fov=fov)          # << pass FOV so DPCN uses it
            loss   = loss_fn(logits, y)

        scaler.scale(loss).backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        scaler.step(optimizer); scaler.update()

        total += loss.item() * x.size(0); n += x.size(0)
    return total / max(1, n)

@torch.no_grad()
def validate_loss_only(model, loader, loss_fn,  window, overlap, device=DEVICE,):
    model.eval()
    total, n = 0.0, 0
    for batch in loader:
        x   = batch["image"].to(device, non_blocking=True)
        y   = batch["mask"].to(device,  non_blocking=True)
        fov = batch.get("fov", torch.ones_like(y)).to(device, non_blocking=True)

        for i in range(x.size(0)):
            logits_i = infer_full_logits(model, x[i:i+1], device=device, window=window, overlap=overlap)
            yi = y[i:i+1] * (fov[i:i+1] > 0.5).float()
            with torch.amp.autocast(device_type="cuda", enabled=(device=="cuda")):
                loss_i = loss_fn(logits_i, yi)
            total += loss_i.item(); n += 1
    return total / max(1, n)

def atomic_torch_save(state, path: Path):
    path = Path(path); tmp = path.with_suffix(path.suffix + ".partial")
    try: tmp.unlink()
    except FileNotFoundError: pass
    with open(tmp, "wb") as f:
        torch.save(state, f); f.flush(); os.fsync(f.fileno())
    os.replace(tmp, path)


def visualize_batch(loader, name="Loader", n_max=None):
    import matplotlib.pyplot as plt
    total_shown = 0
    for b_idx, batch in enumerate(loader):
        imgs = batch["image"]
        masks = batch["mask"]
        img_path = batch["image_path"][0]
        for i in range(imgs.size(0)):
            total_shown += 1
            if n_max and total_shown > n_max:
                print(f"\nStopped after showing {n_max} images.")
                return
            fig, axs = plt.subplots(1, 2, figsize=(6, 3))
            axs[0].imshow(imgs[i, 0].cpu(), cmap="gray")
            axs[0].set_title(f"{name} Image {total_shown} • {Path(img_path).name} ")
            axs[1].imshow(masks[i, 0].cpu(), cmap="gray")
            axs[1].set_title(f"{name} Mask {total_shown}")
            for ax in axs: ax.axis("off")
            plt.tight_layout()
            plt.show()

# %% [markdown]
# # MAIN RUN

# %%
# --- main LOO run ---
def run_chase_experiment(
    root=DATASET_ROOT, label_folder=DATASET_LABELFOLDER, epochs=EPOCHS, warmup=warmup_epochs, V_MULT=V_MULT,
    batch_size=BATCH_SIZE, img_size=IMG_SIZE, patch_train=True, patch_size=PATCH_SIZE, vessel_bias_p=VESSEL_BIAS,
    threshold_eval=THRESHOLD_EVAL, folds=FOLDS, fold_id=0, chckpnt_paths=None
):  
    rng = np.random.RandomState(SEED)
    all_metrics = []
    per_image_preds = {}   # img_stem -> dict(prob_path, bin_path, fold_id)
    
    while fold_id < folds:
        
        # add checkpoint paths to metric list
        if chckpnt_paths:
            for ckpt in chckpnt_paths:
                add_metrics(MODEL_NAME, 
                            DATASET_ROOT, 
                            DATASET_LABELFOLDER,
                            img_size, ckpt, 
                            threshold_eval, all_metrics) 
            chckpnt_paths.clear()

        print(f"\n========== {MODEL_NAME} {DATASET} NEW SPLIT, Fold {fold_id+1}/{folds} ==========")

        tr_pairs, te_pairs, _ = splits[fold_id]

        # 2) carve val deterministically from train
        val_pairs = tr_pairs[-4:]
        tr_pairs_ = tr_pairs[:-4]

        # 3) loaders
        train_loader, val_loader = make_loaders(
            train_pairs=tr_pairs_, val_pairs=val_pairs,
            image_size=IMG_SIZE, batch_size=BATCH_SIZE, num_workers=1,
            seed=SEED + fold_id, strict_fov=True,
            augs_train=get_train_augs(IMG_SIZE),
            augs_val=get_val_augs(IMG_SIZE),
            patch_train=True, patch_size=PATCH_SIZE,
            vessel_bias_p=VESSEL_BIAS, virtual_mult=V_MULT,
        )

        _, test_loader = make_loaders(
            train_pairs=te_pairs, val_pairs=te_pairs,
            image_size=IMG_SIZE, batch_size=1, num_workers=1,
            seed=SEED, strict_fov=True,
            augs_train=None, augs_val=get_val_augs(IMG_SIZE),
        )


        #visualize_batch(train_loader, "Train")
        #visualize_batch(test_loader, "Test")

        # 4) model & optimizer
        model, loss_fn = make_model(MODEL_NAME, train_loader)
        model.uses_fov = MODEL_NAME == "MATHFI"     # whether to pass fov in forward or not

    

        optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-4)
        scaler    = torch.amp.GradScaler("cuda", enabled=(DEVICE=="cuda"))
        def lr_lambda(e):
            if e < warmup: return (e+1)/max(1, warmup)
            progress = (e - warmup) / max(1, epochs - warmup)
            return 0.5 * (1 + math.cos(math.pi * progress))
        scheduler = LambdaLR(optimizer, lr_lambda)

        # 5) train with best-val checkpointing
        best_val = float("inf")
        ckpt_path = SAVE_CKPT / f"{DATASET}_fold{fold_id:02d}.pth"

        train_losses, val_losses = [], []

        for ep in range(1, epochs+1):
            update_dataset(train_loader.dataset, ep)
            t0=time.time()
            tr_loss  = train_one_epoch(model, train_loader, optimizer, scaler, loss_fn)
            val_loss = validate_loss_only(model, val_loader, loss_fn, PATCH_SIZE, VAL_OVERLAP)
            scheduler.step()
            print(f"[F{fold_id:02d} E{ep:03d}] train={tr_loss:.4f} val={val_loss:.4f} "
                  f"lr={optimizer.param_groups[0]['lr']:.2e} time={(time.time()-t0):.1f}s")
            
            
            train_losses.append(float(tr_loss))
            val_losses.append(float(val_loss))

            if val_loss < best_val:
                best_val = val_loss
                atomic_torch_save(model.state_dict(), ckpt_path)
                print(f"\tCHECKPOINT SAVED: {ckpt_path}")
        
        plt.figure(figsize=(6,3.5))
        plt.plot(range(1, len(train_losses)+1), train_losses, label="train")
        plt.plot(range(1, len(val_losses)+1),   val_losses,   label="val")
        plt.xlabel("epoch"); plt.ylabel("loss"); plt.grid(True); plt.legend()
        plt.title("Train vs Val Loss:" + TITLE)
        plt.tight_layout()
        plt.show()

        # 6) eval on left-out image using best checkpoint

        model.load_state_dict(torch.load(ckpt_path, map_location=DEVICE))
        model.eval()

        

        # 6a) metrics
        # 6a) metrics — use YOUR metrics module via our wrapper
        m = evaluate_and_print(model, test_loader, device = DEVICE, threshold=threshold_eval, compute_auc=True)
        m["fold_id"]  = fold_id
        

        # TODO: STORE INDIV .PT
        visualize_samples(
            model=model,
            dataloader=test_loader,
            n_rows=8,
            device=DEVICE,
            threshold=0.5,
            clamp_pred_with_fov=True,
            figsize_per_row=(12, 3),
        )
        batch = next(iter(test_loader))
        img_path = batch["image_path"][0]
        img_stem = Path(img_path).stem
        m["image_id"] = img_stem
        all_metrics.append(m)

        

        fold_id = fold_id + 1

        # END OF FOLD LOOP
    


    # 7) aggregate & save CSV
    import csv
    keys = ["fold_id","image_id","SEN","SPE", "CLDICE", "ACC","Dice","IoU","AUC","AP"]
    csv_path = SAVE_LOGS / f"{DATASET}_newSplit_perfold.csv"
    with open(csv_path, "w", newline="") as f:
        w = csv.DictWriter(f, fieldnames=keys); w.writeheader()
        for row in all_metrics: w.writerow({k: row.get(k, "") for k in keys})

    # mean±std
    def _ms(name):
        arr = np.array([r[name] for r in all_metrics if not np.isnan(r[name])], dtype=float)
        return float(arr.mean()), float(arr.std(ddof=1)) if arr.size > 1 else 0.0
    summary = {k: _ms(k) for k in ["SEN","SPE","CLDICE","ACC","Dice","IoU","AUC","AP"]}
    print(f"\n=== {MODEL_NAME} {DATASET} NEW SPLITS ({FOLDS} folds) — mean ± std ===")
    for k,(mu,sig) in summary.items():
        print(f"{k}: {mu:.4f} ± {sig:.4f}")

    with open(SAVE_LOGS / f"{DATASET}_newSplit_summary.json","w") as f:
        json.dump({k: {"mean": mu, "std": sig} for k,(mu,sig) in summary.items()}, f, indent=2)

    # 8) (optional) gallery index of unbiased predictions
    with open(SAVE_LOGS / f"{DATASET}_newSplit_per_image_preds.json","w") as f:
        json.dump(per_image_preds, f, indent=2)

    return all_metrics, summary

# %%
# Check indiv chkpoint paths scores
"""
check_checkpoints = [
 "..\..\..\..\pth\FR-UNet_STARE_NEWSPLIT\checkpoints\STARE_fold00.pth",
]

for checkpoint in check_checkpoints:
    add_metrics(MODEL_NAME, 
                DATASET_ROOT, 
                DATASET_LABELFOLDER,
                IMG_SIZE, 
                checkpoint,
                THRESHOLD_EVAL, [])

"""
# Out:
# '\ncheck_checkpoints = [\n "..\\..\\..\\..\\pth\\FR-UNet_STARE_NEWSPLIT\\checkpoints\\STARE_fold00.pth",\n]\n\nfor checkpoint in check_checkpoints:\n    add_metrics(MODEL_NAME, \n                DATASET_ROOT, \n                DATASET_LABELFOLDER,\n                IMG_SIZE, \n                checkpoint,\n                THRESHOLD_EVAL, [])\n\n'

# %%
"""
path = r"..\..\..\..\pth\FR-UNet_STARE_NEWSPLIT\predictions\01_test__fold00.pt"
data = torch.load(path, map_location="cpu")

stem = Path(path).stem  # "STARE_fold00"
fold_id = int(stem.split("fold")[-1])  # 0

_, te_pairs = stare_loo_fold(DATASET_ROOT, label_folder=DATASET_LABELFOLDER, fold_id=fold_id)

_, test_loader = make_loaders(
    train_pairs=te_pairs, val_pairs=te_pairs,
    image_size=IMG_SIZE, batch_size=1, num_workers=1,
    seed=SEED, strict_fov=True,
    augs_train=None, augs_val=get_val_augs(IMG_SIZE),
)

batch = next(iter(test_loader))
x   = batch["image"].to(DEVICE)
y   = batch["mask"].to(DEVICE)
logits = data["logits"]   # raw model outputs before sigmoid
prob   = data["prob"]     # probability map (0–1)
binm   = data["bin"]      # binary mask (0 or 1)
img_path = data["image_path"]
fold_id = data["fold"]
img_stem = Path(batch["image_path"][0]).stem

fig, axs = plt.subplots(1,4, figsize=(12,3))
axs[0].imshow(x[0,0].cpu(), cmap="gray"); axs[0].set_title("Image"); axs[0].axis("off")
axs[1].imshow(y[0,0].cpu(), cmap="gray"); axs[1].set_title("GT");    axs[1].axis("off")
axs[2].imshow(prob[0,0].cpu(), cmap="gray"); axs[2].set_title("Prob"); axs[2].axis("off")
axs[3].imshow(binm[0,0].cpu(), cmap="gray"); axs[3].set_title(f"Pred@0.5"); axs[3].axis("off")
fig.suptitle(f"{DATASET} NEW SPLITS Fold {fold_id} — {img_stem}")
plt.tight_layout(); plt.show()

"""
# Out:
# '\npath = r"..\\..\\..\\..\\pth\\FR-UNet_STARE_NEWSPLIT\\predictions\x01_test__fold00.pt"\ndata = torch.load(path, map_location="cpu")\n\nstem = Path(path).stem  # "STARE_fold00"\nfold_id = int(stem.split("fold")[-1])  # 0\n\n_, te_pairs = stare_loo_fold(DATASET_ROOT, label_folder=DATASET_LABELFOLDER, fold_id=fold_id)\n\n_, test_loader = make_loaders(\n    train_pairs=te_pairs, val_pairs=te_pairs,\n    image_size=IMG_SIZE, batch_size=1, num_workers=1,\n    seed=SEED, strict_fov=True,\n    augs_train=None, augs_val=get_val_augs(IMG_SIZE),\n)\n\nbatch = next(iter(test_loader))\nx   = batch["image"].to(DEVICE)\ny   = batch["mask"].to(DEVICE)\nlogits = data["logits"]   # raw model outputs before sigmoid\nprob   = data["prob"]     # probability map (0–1)\nbinm   = data["bin"]      # binary mask (0 or 1)\nimg_path = data["image_path"]\nfold_id = data["fold"]\nimg_stem = Path(batch["image_path"][0]).stem\n\nfig, axs = plt.subplots(1,4, figsize=(12,3))\naxs[0].imshow(x[0,0].cpu(), cmap="gray"); axs[0].set_title("Image"); axs[0].axis("off")\naxs[1].imshow(y[0,0].cpu(), cmap="gray"); axs[1].set_title("GT");    axs[1].axis("off")\naxs[2].imshow(prob[0,0].cpu(), cmap="gray"); axs[2].set_title("Prob"); axs[2].axis("off")\naxs[3].imshow(binm[0,0].cpu(), cmap="gray"); axs[3].set_title(f"Pred@0.5"); axs[3].axis("off")\nfig.suptitle(f"{DATASET} NEW SPLITS Fold {fold_id} — {img_stem}")\nplt.tight_layout(); plt.show()\n\n'

# %%
all_metrics, summary = run_chase_experiment(
    root=DATASET_ROOT,
    label_folder=DATASET_LABELFOLDER,
    epochs=EPOCHS,
    warmup=warmup_epochs,
    batch_size=BATCH_SIZE,
    img_size=IMG_SIZE,
    patch_train=True,
    patch_size=PATCH_SIZE,
    vessel_bias_p=VESSEL_BIAS,
    threshold_eval=THRESHOLD_EVAL,
    folds=FOLDS,
    fold_id=FOLD_ID,   #starts at any fold_id

    chckpnt_paths= [
        #"..\..\..\..\pth\{MODEL_NAME}_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth",
        #"..\..\..\..\pth\{MODEL_NAME}_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth",
        # "..\..\..\..\pth\{MODEL_NAME}_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth"

    ]
)
# Out:
# ========== MATHFI CHASEDB1 NEW SPLIT, Fold 1/5 ==========
# [F00 E001] train=0.9778 val=1.0880 lr=1.20e-04 time=32.2s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E002] train=0.7156 val=0.7969 lr=1.80e-04 time=46.5s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E003] train=0.5735 val=0.6596 lr=2.40e-04 time=29.8s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E004] train=0.4709 val=0.6843 lr=3.00e-04 time=26.8s
# [F00 E005] train=0.4150 val=0.5562 lr=3.00e-04 time=29.5s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E006] train=0.3845 val=0.5525 lr=3.00e-04 time=38.3s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E007] train=0.3603 val=0.4634 lr=2.99e-04 time=41.7s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E008] train=0.3563 val=0.4496 lr=2.97e-04 time=42.4s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E009] train=0.3392 val=0.3735 lr=2.94e-04 time=32.5s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E010] train=0.3231 val=0.3779 lr=2.91e-04 time=39.8s
# [F00 E011] train=0.3274 val=0.4370 lr=2.87e-04 time=47.1s
# [F00 E012] train=0.3300 val=0.4661 lr=2.82e-04 time=34.2s
# [F00 E013] train=0.3254 val=0.3618 lr=2.77e-04 time=26.7s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E014] train=0.3270 val=0.4121 lr=2.71e-04 time=26.4s
# [F00 E015] train=0.3259 val=0.3536 lr=2.65e-04 time=27.2s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E016] train=0.3117 val=0.3116 lr=2.58e-04 time=26.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth
# [F00 E017] train=0.3065 val=0.3423 lr=2.50e-04 time=26.6s
# [F00 E018] train=0.3070 val=0.4494 lr=2.42e-04 time=32.0s
# [F00 E019] train=0.3071 val=0.3808 lr=2.34e-04 time=28.1s
# [F00 E020] train=0.3062 val=0.4545 lr=2.25e-04 time=28.2s
# [F00 E021] train=0.2908 val=0.3424 lr=2.16e-04 time=26.4s
# [F00 E022] train=0.2832 val=0.4106 lr=2.06e-04 time=27.5s
# [F00 E023] train=0.2905 val=0.4138 lr=1.96e-04 time=26.9s
# [F00 E024] train=0.3092 val=0.4301 lr=1.86e-04 time=26.8s
# [F00 E025] train=0.2996 val=0.4091 lr=1.76e-04 time=27.3s
# [F00 E026] train=0.2979 val=0.3759 lr=1.66e-04 time=26.7s
# [F00 E027] train=0.3006 val=0.4018 lr=1.55e-04 time=26.4s
# [F00 E028] train=0.3041 val=0.5111 lr=1.45e-04 time=26.6s
# [F00 E029] train=0.2941 val=0.3689 lr=1.34e-04 time=26.8s
# [F00 E030] train=0.2941 val=0.4163 lr=1.24e-04 time=26.4s
# [F00 E031] train=0.2952 val=0.4342 lr=1.14e-04 time=26.5s
# [F00 E032] train=0.2845 val=0.5067 lr=1.04e-04 time=26.4s
# [F00 E033] train=0.2806 val=0.3760 lr=9.38e-05 time=27.4s
# [F00 E034] train=0.2963 val=0.4076 lr=8.42e-05 time=27.6s
# [F00 E035] train=0.2960 val=0.4152 lr=7.50e-05 time=27.2s
# [F00 E036] train=0.2808 val=0.4777 lr=6.61e-05 time=27.0s
# [F00 E037] train=0.2815 val=0.3734 lr=5.77e-05 time=27.1s
# [F00 E038] train=0.2713 val=0.3767 lr=4.96e-05 time=27.6s
# [F00 E039] train=0.2707 val=0.3621 lr=4.21e-05 time=27.1s
# [F00 E040] train=0.2596 val=0.3722 lr=3.51e-05 time=26.4s
# [F00 E041] train=0.2743 val=0.4338 lr=2.86e-05 time=26.4s
# [F00 E042] train=0.2639 val=0.3790 lr=2.28e-05 time=27.1s
# [F00 E043] train=0.2561 val=0.4243 lr=1.76e-05 time=26.8s
# [F00 E044] train=0.2585 val=0.4556 lr=1.30e-05 time=26.2s
# [F00 E045] train=0.2604 val=0.3600 lr=9.05e-06 time=26.4s
# [F00 E046] train=0.2376 val=0.3974 lr=5.81e-06 time=32.4s
# [F00 E047] train=0.2425 val=0.3908 lr=3.28e-06 time=32.2s
# [F00 E048] train=0.2300 val=0.3884 lr=1.46e-06 time=31.6s
# [F00 E049] train=0.2330 val=0.3932 lr=3.65e-07 time=31.8s
# [F00 E050] train=0.2334 val=0.3800 lr=0.00e+00 time=32.0s
# === Test Set Evaluation Metrics ===
# -- Macro (per-image mean) --
# Sensitivity    : 0.7435
# Specificity    : 0.9870
# clDice         : 0.7272
# Accuracy       : 0.9715
# Dice           : 0.7615
# IoU            : 0.6157
# Precision      : 0.7890
# FPR            : 0.0130
# FDR            : 0.2110
# Dice_thin      : 0.4333
# Dice_thick     : 0.6540
# ROC_AUC        : 0.9764
# PR_AUC         : 0.8485
# -- Micro (pooled over all pixels) --
# Sensitivity    : 0.7376
# Specificity    : 0.9870
# F1/Dice        : 0.7626
# Accuracy       : 0.9715
# IoU            : 0.6163
# Precision      : 0.7894
# FPR            : 0.0130
# FDR            : 0.2106
# ROC_AUC        : 0.9754
# PR_AUC         : 0.8423
# ========== MATHFI CHASEDB1 NEW SPLIT, Fold 2/5 ==========
# [F01 E001] train=1.0453 val=1.1082 lr=1.20e-04 time=27.3s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E002] train=0.7673 val=0.8443 lr=1.80e-04 time=26.7s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E003] train=0.5942 val=0.8584 lr=2.40e-04 time=26.5s
# [F01 E004] train=0.4958 val=0.5846 lr=3.00e-04 time=27.1s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E005] train=0.4372 val=0.5306 lr=3.00e-04 time=26.6s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E006] train=0.4068 val=0.4831 lr=3.00e-04 time=26.4s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E007] train=0.3849 val=0.5214 lr=2.99e-04 time=26.4s
# [F01 E008] train=0.3723 val=0.4532 lr=2.97e-04 time=27.3s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E009] train=0.3538 val=0.4240 lr=2.94e-04 time=27.6s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E010] train=0.3441 val=0.3915 lr=2.91e-04 time=27.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E011] train=0.3402 val=0.4855 lr=2.87e-04 time=27.3s
# [F01 E012] train=0.3566 val=0.6147 lr=2.82e-04 time=26.6s
# [F01 E013] train=0.3448 val=0.4340 lr=2.77e-04 time=27.5s
# [F01 E014] train=0.3376 val=0.6548 lr=2.71e-04 time=27.0s
# [F01 E015] train=0.3344 val=0.5823 lr=2.65e-04 time=26.7s
# [F01 E016] train=0.3275 val=0.3740 lr=2.58e-04 time=26.5s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E017] train=0.3237 val=0.4127 lr=2.50e-04 time=26.7s
# [F01 E018] train=0.3273 val=0.3816 lr=2.42e-04 time=26.9s
# [F01 E019] train=0.3201 val=0.4616 lr=2.34e-04 time=26.4s
# [F01 E020] train=0.3133 val=0.3340 lr=2.25e-04 time=26.4s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth
# [F01 E021] train=0.2972 val=0.3936 lr=2.16e-04 time=26.4s
# [F01 E022] train=0.2990 val=0.4227 lr=2.06e-04 time=28.1s
# [F01 E023] train=0.2988 val=0.4161 lr=1.96e-04 time=26.5s
# [F01 E024] train=0.2915 val=0.4201 lr=1.86e-04 time=27.4s
# [F01 E025] train=0.2936 val=0.3840 lr=1.76e-04 time=26.7s
# [F01 E026] train=0.2952 val=0.4715 lr=1.66e-04 time=27.2s
# [F01 E027] train=0.3043 val=0.3911 lr=1.55e-04 time=27.1s
# [F01 E028] train=0.2997 val=0.3461 lr=1.45e-04 time=26.8s
# [F01 E029] train=0.2975 val=0.4107 lr=1.34e-04 time=26.6s
# [F01 E030] train=0.3036 val=0.3549 lr=1.24e-04 time=26.8s
# [F01 E031] train=0.2971 val=0.4365 lr=1.14e-04 time=27.5s
# [F01 E032] train=0.2892 val=0.4439 lr=1.04e-04 time=26.2s
# [F01 E033] train=0.2902 val=0.4116 lr=9.38e-05 time=26.5s
# [F01 E034] train=0.2852 val=0.4110 lr=8.42e-05 time=26.4s
# [F01 E035] train=0.2835 val=0.3827 lr=7.50e-05 time=27.2s
# [F01 E036] train=0.2803 val=0.4623 lr=6.61e-05 time=27.4s
# [F01 E037] train=0.2796 val=0.3966 lr=5.77e-05 time=26.9s
# [F01 E038] train=0.2752 val=0.4336 lr=4.96e-05 time=27.1s
# [F01 E039] train=0.2707 val=0.3963 lr=4.21e-05 time=26.7s
# [F01 E040] train=0.2721 val=0.3756 lr=3.51e-05 time=27.0s
# [F01 E041] train=0.2709 val=0.3662 lr=2.86e-05 time=27.5s
# [F01 E042] train=0.2652 val=0.3556 lr=2.28e-05 time=26.7s
# [F01 E043] train=0.2640 val=0.4071 lr=1.76e-05 time=26.5s
# [F01 E044] train=0.2608 val=0.4199 lr=1.30e-05 time=27.0s
# [F01 E045] train=0.2577 val=0.5018 lr=9.05e-06 time=26.8s
# [F01 E046] train=0.2526 val=0.4525 lr=5.81e-06 time=31.5s
# [F01 E047] train=0.2501 val=0.4343 lr=3.28e-06 time=31.4s
# [F01 E048] train=0.2499 val=0.4411 lr=1.46e-06 time=32.6s
# [F01 E049] train=0.2518 val=0.4456 lr=3.65e-07 time=31.7s
# [F01 E050] train=0.2454 val=0.4437 lr=0.00e+00 time=32.2s
# === Test Set Evaluation Metrics ===
# -- Macro (per-image mean) --
# Sensitivity    : 0.8325
# Specificity    : 0.9748
# clDice         : 0.7622
# Accuracy       : 0.9647
# Dice           : 0.7597
# IoU            : 0.6131
# Precision      : 0.7038
# FPR            : 0.0252
# FDR            : 0.2962
# Dice_thin      : 0.4593
# Dice_thick     : 0.6423
# ROC_AUC        : 0.9797
# PR_AUC         : 0.8490
# -- Micro (pooled over all pixels) --
# Sensitivity    : 0.8270
# Specificity    : 0.9748
# F1/Dice        : 0.7610
# Accuracy       : 0.9647
# IoU            : 0.6142
# Precision      : 0.7048
# FPR            : 0.0252
# FDR            : 0.2952
# ROC_AUC        : 0.9789
# PR_AUC         : 0.8429
# ========== MATHFI CHASEDB1 NEW SPLIT, Fold 3/5 ==========
# [F02 E001] train=1.2485 val=1.2259 lr=1.20e-04 time=26.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E002] train=0.9392 val=1.0542 lr=1.80e-04 time=27.4s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E003] train=0.7071 val=0.7846 lr=2.40e-04 time=27.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E004] train=0.5596 val=0.8400 lr=3.00e-04 time=26.5s
# [F02 E005] train=0.4605 val=0.5653 lr=3.00e-04 time=26.9s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E006] train=0.4197 val=0.5840 lr=3.00e-04 time=27.0s
# [F02 E007] train=0.3847 val=0.5672 lr=2.99e-04 time=27.3s
# [F02 E008] train=0.3748 val=0.7326 lr=2.97e-04 time=26.4s
# [F02 E009] train=0.3531 val=0.4960 lr=2.94e-04 time=26.2s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E010] train=0.3323 val=0.4325 lr=2.91e-04 time=27.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E011] train=0.3440 val=0.4161 lr=2.87e-04 time=27.2s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E012] train=0.3385 val=0.4380 lr=2.82e-04 time=26.7s
# [F02 E013] train=0.3333 val=0.3851 lr=2.77e-04 time=27.4s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E014] train=0.3382 val=0.3854 lr=2.71e-04 time=26.5s
# [F02 E015] train=0.3272 val=0.3774 lr=2.65e-04 time=27.4s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E016] train=0.3216 val=0.3758 lr=2.58e-04 time=27.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E017] train=0.3204 val=0.3871 lr=2.50e-04 time=26.9s
# [F02 E018] train=0.3082 val=0.3702 lr=2.42e-04 time=26.5s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E019] train=0.3118 val=0.3781 lr=2.34e-04 time=27.5s
# [F02 E020] train=0.3054 val=0.3739 lr=2.25e-04 time=26.8s
# [F02 E021] train=0.3018 val=0.3737 lr=2.16e-04 time=38.6s
# [F02 E022] train=0.3082 val=0.3383 lr=2.06e-04 time=43.0s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth
# [F02 E023] train=0.3029 val=0.3870 lr=1.96e-04 time=43.3s
# [F02 E024] train=0.3045 val=0.3864 lr=1.86e-04 time=43.4s
# [F02 E025] train=0.2999 val=0.3599 lr=1.76e-04 time=43.3s
# [F02 E026] train=0.2955 val=0.3555 lr=1.66e-04 time=43.4s
# [F02 E027] train=0.2945 val=0.3655 lr=1.55e-04 time=43.6s
# [F02 E028] train=0.2962 val=0.3569 lr=1.45e-04 time=43.5s
# [F02 E029] train=0.3007 val=0.3596 lr=1.34e-04 time=43.5s
# [F02 E030] train=0.3028 val=0.3826 lr=1.24e-04 time=43.2s
# [F02 E031] train=0.2972 val=0.4107 lr=1.14e-04 time=28.8s
# [F02 E032] train=0.2937 val=0.3658 lr=1.04e-04 time=26.8s
# [F02 E033] train=0.2942 val=0.3557 lr=9.38e-05 time=26.9s
# [F02 E034] train=0.2962 val=0.3819 lr=8.42e-05 time=27.1s
# [F02 E035] train=0.2846 val=0.3476 lr=7.50e-05 time=26.8s
# [F02 E036] train=0.2896 val=0.3761 lr=6.61e-05 time=27.3s
# [F02 E037] train=0.2768 val=0.3780 lr=5.77e-05 time=26.6s
# [F02 E038] train=0.2885 val=0.3646 lr=4.96e-05 time=26.5s
# [F02 E039] train=0.2831 val=0.3714 lr=4.21e-05 time=26.3s
# [F02 E040] train=0.2809 val=0.3560 lr=3.51e-05 time=27.0s
# [F02 E041] train=0.2783 val=0.3884 lr=2.86e-05 time=26.6s
# [F02 E042] train=0.2769 val=0.4562 lr=2.28e-05 time=26.5s
# [F02 E043] train=0.2781 val=0.4319 lr=1.76e-05 time=26.4s
# [F02 E044] train=0.2798 val=0.3863 lr=1.30e-05 time=26.8s
# [F02 E045] train=0.2793 val=0.3866 lr=9.05e-06 time=27.7s
# [F02 E046] train=0.2661 val=0.3962 lr=5.81e-06 time=31.6s
# [F02 E047] train=0.2620 val=0.3898 lr=3.28e-06 time=38.2s
# [F02 E048] train=0.2604 val=0.3856 lr=1.46e-06 time=45.1s
# [F02 E049] train=0.2688 val=0.3739 lr=3.65e-07 time=47.0s
# [F02 E050] train=0.2655 val=0.3962 lr=0.00e+00 time=47.5s
# === Test Set Evaluation Metrics ===
# -- Macro (per-image mean) --
# Sensitivity    : 0.7171
# Specificity    : 0.9883
# clDice         : 0.7506
# Accuracy       : 0.9709
# Dice           : 0.7583
# IoU            : 0.6113
# Precision      : 0.8068
# FPR            : 0.0117
# FDR            : 0.1932
# Dice_thin      : 0.4619
# Dice_thick     : 0.6454
# ROC_AUC        : 0.9638
# PR_AUC         : 0.8350
# -- Micro (pooled over all pixels) --
# Sensitivity    : 0.7188
# Specificity    : 0.9883
# F1/Dice        : 0.7616
# Accuracy       : 0.9709
# IoU            : 0.6150
# Precision      : 0.8098
# FPR            : 0.0117
# FDR            : 0.1902
# ROC_AUC        : 0.9640
# PR_AUC         : 0.8362
# ========== MATHFI CHASEDB1 NEW SPLIT, Fold 4/5 ==========
# [F03 E001] train=1.0455 val=1.1526 lr=1.20e-04 time=43.4s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold03.pth
# [F03 E002] train=0.7768 val=0.8253 lr=1.80e-04 time=43.7s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold03.pth
# [F03 E003] train=0.5979 val=0.7211 lr=2.40e-04 time=43.2s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold03.pth
# [F03 E004] train=0.4920 val=0.4945 lr=3.00e-04 time=42.4s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold03.pth
# [F03 E005] train=0.4330 val=0.4628 lr=3.00e-04 time=27.6s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold03.pth
# [F03 E006] train=0.4007 val=0.5226 lr=3.00e-04 time=27.6s
# [F03 E007] train=0.3873 val=0.4177 lr=2.99e-04 time=27.6s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold03.pth
# [F03 E008] train=0.3720 val=0.4353 lr=2.97e-04 time=26.7s
# [F03 E009] train=0.3551 val=0.3632 lr=2.94e-04 time=26.4s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold03.pth
# [F03 E010] train=0.3408 val=0.3702 lr=2.91e-04 time=26.9s
# [F03 E011] train=0.3428 val=0.3328 lr=2.87e-04 time=26.8s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold03.pth
# [F03 E012] train=0.3345 val=0.3515 lr=2.82e-04 time=26.2s
# [F03 E013] train=0.3328 val=0.3893 lr=2.77e-04 time=26.4s
# [F03 E014] train=0.3322 val=0.3548 lr=2.71e-04 time=26.3s
# [F03 E015] train=0.3201 val=0.3582 lr=2.65e-04 time=27.5s
# [F03 E016] train=0.3267 val=0.3601 lr=2.58e-04 time=27.1s
# [F03 E017] train=0.3214 val=0.3219 lr=2.50e-04 time=27.2s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold03.pth
# [F03 E018] train=0.3119 val=0.3440 lr=2.42e-04 time=27.4s
# [F03 E019] train=0.3081 val=0.3172 lr=2.34e-04 time=27.1s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold03.pth
# [F03 E020] train=0.3157 val=0.3491 lr=2.25e-04 time=27.4s
# [F03 E021] train=0.3044 val=0.3345 lr=2.16e-04 time=27.1s
# [F03 E022] train=0.3004 val=0.3280 lr=2.06e-04 time=26.9s
# [F03 E023] train=0.3040 val=0.3294 lr=1.96e-04 time=26.5s
# [F03 E024] train=0.3002 val=0.3517 lr=1.86e-04 time=26.6s
# [F03 E025] train=0.2999 val=0.3234 lr=1.76e-04 time=26.6s
# [F03 E026] train=0.2954 val=0.3220 lr=1.66e-04 time=26.3s
# [F03 E027] train=0.2976 val=0.3155 lr=1.55e-04 time=26.3s
# 	CHECKPOINT SAVED: ..\..\..\..\pth\MATHFI_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold03.pth
# [F03 E028] train=0.3009 val=0.3232 lr=1.45e-04 time=27.0s
# [F03 E029] train=0.2963 val=0.3340 lr=1.34e-04 time=34.4s
# [F03 E030] train=0.2983 val=0.3467 lr=1.24e-04 time=26.7s
# [F03 E031] train=0.2883 val=0.3542 lr=1.14e-04 time=27.1s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 all_metrics, summary = run_chase_experiment(
#       2     root=DATASET_ROOT,
#       3     label_folder=DATASET_LABELFOLDER,
#       4     epochs=EPOCHS,
#       5     warmup=warmup_epochs,
#       6     batch_size=BATCH_SIZE,
#       7     img_size=IMG_SIZE,
#       8     patch_train=True,
#       9     patch_size=PATCH_SIZE,
#      10     vessel_bias_p=VESSEL_BIAS,
#      11     threshold_eval=THRESHOLD_EVAL,
#      12     folds=FOLDS,
#      13     fold_id=FOLD_ID,   #starts at any fold_id
#      14
#      15     chckpnt_paths= [
#      16         #"..\..\..\..\pth\{MODEL_NAME}_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold00.pth",
#      17         #"..\..\..\..\pth\{MODEL_NAME}_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold01.pth",
#      18         # "..\..\..\..\pth\{MODEL_NAME}_CHASEDB1_NEWSPLIT\checkpoints\CHASEDB1_fold02.pth"
#      19
#      20     ]
#      21 )
#
# Cell In[9], line 76, in run_chase_experiment(root, label_folder, epochs, warmup, V_MULT, batch_size, img_size, patch_train, patch_size, vessel_bias_p, threshold_eval, folds, fold_id, chckpnt_paths)
#      74 update_dataset(train_loader.dataset, ep)
#      75 t0=time.time()
# ---> 76 tr_loss  = train_one_epoch(model, train_loader, optimizer, scaler, loss_fn)
#      77 val_loss = validate_loss_only(model, val_loader, loss_fn, PATCH_SIZE, VAL_OVERLAP)
#      78 scheduler.step()
#
# Cell In[8], line 165, in train_one_epoch(model, loader, optimizer, scaler, loss_fn, device)
#     162     else: logits = model(x)
#     163     loss   = loss_fn(logits, y)
# --> 165 scaler.scale(loss).backward()
#     166 torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
#     167 scaler.step(optimizer); scaler.update()
#
# File c:\Users\s1005\OneDrive\文件\PLM_DOCS\code\githubs\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation\venv310\lib\site-packages\torch\_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)
#     645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File c:\Users\s1005\OneDrive\文件\PLM_DOCS\code\githubs\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation\venv310\lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File c:\Users\s1005\OneDrive\文件\PLM_DOCS\code\githubs\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation\venv310\lib\site-packages\torch\autograd\graph.py:829, in _engine_run_backward(t_outputs, *args, **kwargs)
#     827     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828 try:
# --> 829     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830         t_outputs, *args, **kwargs
#     831     )  # Calls into the C++ engine to run the backward pass
#     832 finally:
#     833     if attach_logging_hooks:
#
# KeyboardInterrupt:
