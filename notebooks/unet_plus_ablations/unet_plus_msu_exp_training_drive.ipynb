# %% [markdown]
# # Unet+ + MSU Training Exp for DRIVE dataset (w + wo augs)

# %%
# Add project root (the folder that contains "src/") to sys.path
import sys
import time
from pathlib import Path

def add_project_root(marker_dir="src", max_hops=5):
    p = Path.cwd().resolve()
    for _ in range(max_hops):
        if (p / marker_dir).exists():
            sys.path.insert(0, str(p))
            print(f"[OK] Added to sys.path: {p}")
            return
        p = p.parent
    raise RuntimeError(f"Could not find '{marker_dir}' within {max_hops} parents from {Path.cwd()}")

add_project_root()  # looks for a "src" sibling/parent of the notebook
# Out:
# [OK] Added to sys.path: D:\Data\Projects\Thesis\Adaptive-Hierarchical-Feature-Modulation-U-Net-Model-for-Retinal-Vessel-Segmentation

# %%
import os, json, time, math, random
from pathlib import Path

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

# --- data utils ---
from src.data.prepare_dataset import (
    build_pairs_for_split,
    build_all_train_pairs,
    assert_dataset_layout,
    sanity_check_sample_alignment,
)
from src.data.dataloader import make_loaders
from src.data.augmentations import get_train_augs, get_val_augs

from src.models.unet_exp.unetplus_msu import UNetBaselinePlusMSU

# --- evaluation & visualization ---
from src.evaluation.evaluate import evaluate_and_print
from src.evaluation.visualization import visualize_samples

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
SAVE_DIR = Path("./runs/unetplus_ablation/checkpoints/drive")
SAVE_DIR.mkdir(parents=True, exist_ok=True)
SEED = 1337
torch.manual_seed(SEED); np.random.seed(SEED); random.seed(SEED)
torch.backends.cudnn.benchmark = True

# %%
data_dir = "../../data/raw/DRIVE"

train_pairs = build_pairs_for_split(dataset_root=data_dir, split="training", label_folder="1st_manual")
test_pairs  = build_pairs_for_split(dataset_root=data_dir, split="test",     label_folder="1st_manual")

train_loader, test_loader = make_loaders(
    train_pairs=train_pairs,
    val_pairs=test_pairs,      # <- this becomes the second loader we call "test_loader"
    image_size=512,
    batch_size=2,
    num_workers=4,             # Windows notebook → keep 0
    seed=1337,
    strict_fov=True,
    # augs_train= None,
    # augs_val = None
    augs_train=get_train_augs(512),   # real augmentations
    augs_val=get_val_augs(512),       # deterministic preprocessing (no random augs)
)

# %%
# ---- model instantiation (pure UNet) ----
# If you estimated 'p' earlier via estimate_class_weights, use it; else default to 0.10
pos_prior = p if 'p' in locals() else 0.10

model_core = UNetBaselinePlusMSU(
    in_channels=1,
    base_ch=64,
    bottleneck_dropout=0.10,
    init_pos_prior=pos_prior
).to(DEVICE)

# param count
print(sum(x.numel() for x in model_core.parameters() if x.requires_grad)/1e6, "M params")
# Out:
# 45.660225 M params

# %%
from src.training.loss_functions import DiceBCEComplementLoss
import torch

# (optional) estimate class weights from a few batches to handle heavy imbalance
def estimate_class_weights(loader, max_batches=20):
    with torch.no_grad():
        s = 0.0; n = 0
        for i, b in enumerate(loader):
            s += b["mask"].float().mean().item()  # foreground fraction in [0,1]
            n += 1
            if i+1 >= max_batches: break
    p = max(1e-6, min(1-1e-6, s / max(1, n)))      # foreground prior
    w1 = 1.0 / p                                    # weight FG inversely to its freq
    w0 = 1.0 / (1.0 - p)                            # weight BG inversely to its freq
    # normalize so w0 + w1 ≈ 2 (keeps scale stable)
    s2 = w0 + w1
    w0 = 2.0 * w0 / s2; w1 = 2.0 * w1 / s2
    return w0, w1, p

w0, w1, p = estimate_class_weights(train_loader, max_batches=20)
print(f"~ foreground prior p ≈ {p:.5f} | class weights -> w0={w0:.3f}, w1={w1:.3f}")

loss_fn = DiceBCEComplementLoss(
    w0=w0, w1=w1,
    dice_weight=0.5,         # tune (e.g., 0.6 Dice / 0.4 BCE)
    bce_weight=0.5,
    exact_equation=False,    # keep False so the BCE term is minimized (not added)
    reduction="mean",
)
# Out:
# ~ foreground prior p ≈ 0.08231 | class weights -> w0=0.165, w1=1.835

# %%
def train_one_epoch(model, loader, optimizer, scaler, loss_fn):
    model.train()
    total, n = 0.0, 0
    for batch in loader:
        x = batch["image"].to(DEVICE, non_blocking=True)  # [B,1,H,W]
        y = batch["mask"].to(DEVICE,  non_blocking=True)  # [B,1,H,W]

        # Optional: mask labels outside FOV if present (keeps loss fair)
        if "fov" in batch:
            fov = batch["fov"].to(DEVICE, non_blocking=True)
            y = y * (fov > 0.5).float()

        optimizer.zero_grad(set_to_none=True)
        with torch.amp.autocast(device_type="cuda", enabled=(DEVICE=="cuda")):
            logits = model(x)          # ← PURE UNET: no fov passed
            loss   = loss_fn(logits, y)

        scaler.scale(loss).backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        scaler.step(optimizer)
        scaler.update()

        total += loss.item() * x.size(0)
        n     += x.size(0)
    return total / max(1, n)

@torch.no_grad()
def validate_loss_only(model, loader, loss_fn):
    model.eval()
    total, n = 0.0, 0
    for batch in loader:
        x = batch["image"].to(DEVICE, non_blocking=True)
        y = batch["mask"].to(DEVICE,  non_blocking=True)

        if "fov" in batch:
            fov = batch["fov"].to(DEVICE, non_blocking=True)
            y = y * (fov > 0.5).float()

        with torch.amp.autocast(device_type="cuda", enabled=(DEVICE=="cuda")):
            logits = model(x)          # ← PURE UNET
            loss   = loss_fn(logits, y)

        total += loss.item() * x.size(0)
        n     += x.size(0)
    return total / max(1, n)

# %%
# PTH FILES
LAST_PTH_WO_AUGS = "last_unetplus_msu_wo_aug_drive.pth"
BEST_PTH_WO_AUGS_PTH = "best_unetplus_msu_wo_aug_drive.json"
BEST_PTH_WO_AUGS_JSON = "best_unetplus_msu_wo_aug_drive.pth"

LAST_PTH_W_AUGS = "last_unetplus_msu_w_aug_drive.pth"
BEST_PTH_W_AUGS_PTH = "best_unetplus_msu_w_aug_drive.json"
BEST_PTH_W_AUGS_JSON = "best_unetplus_msu_w_aug_drive.pth"

# %%
import json, time, math
from torch.optim.lr_scheduler import LambdaLR

# --- optimizer / scaler / scheduler ---
optimizer = torch.optim.AdamW(model_core.parameters(), lr=3e-4, weight_decay=1e-4)
scaler    = torch.amp.GradScaler("cuda", enabled=(DEVICE=="cuda"))

EPOCHS = 100
warmup_epochs = 5

def lr_lambda(e):
    if e < warmup_epochs:
        return (e + 1) / warmup_epochs
    progress = (e - warmup_epochs) / max(1, EPOCHS - warmup_epochs)
    return 0.5 * (1 + math.cos(math.pi * progress))

scheduler = LambdaLR(optimizer, lr_lambda)

best_val = float("inf")

# --- lists to collect losses for plotting later ---
train_losses, val_losses = [], []

for epoch in range(1, EPOCHS+1):
    print(f"----- EPOCH {epoch} -----")
    if DEVICE == "cuda": torch.cuda.synchronize()
    t0 = time.time()

    tr_loss  = train_one_epoch(model_core, train_loader, optimizer, scaler, loss_fn)
    val_loss = validate_loss_only(model_core, test_loader, loss_fn)
    scheduler.step()

    if DEVICE == "cuda": torch.cuda.synchronize()
    print(f"[{epoch:03d}] train={tr_loss:.4f} val={val_loss:.4f} "
          f"lr={optimizer.param_groups[0]['lr']:.3e} time={(time.time()-t0):.1f}s")

    # record
    train_losses.append(float(tr_loss))
    val_losses.append(float(val_loss))

    # checkpoints
    torch.save(model_core.state_dict(), SAVE_DIR / "last_unetplus_msu_wo_aug_drive.pth")
    if val_loss < best_val:
        best_val = val_loss
        torch.save(model_core.state_dict(), SAVE_DIR / "best_unetplus_msu_wo_aug_drive.pth")
        with open(SAVE_DIR / "best_unetplus_msu_wo_aug_drive.json","w") as f:
            json.dump({"epoch": epoch, "val_loss": float(val_loss)}, f, indent=2)
# Out:
# ----- EPOCH 1 -----
# [001] train=3.1308 val=1.0737 lr=1.200e-04 time=40.4s
# ----- EPOCH 2 -----
# [002] train=1.1738 val=0.8915 lr=1.800e-04 time=25.2s
# ----- EPOCH 3 -----
# [003] train=1.6766 val=1.3040 lr=2.400e-04 time=26.0s
# ----- EPOCH 4 -----
# [004] train=1.5107 val=0.9455 lr=3.000e-04 time=25.1s
# ----- EPOCH 5 -----
# [005] train=1.2240 val=1.0965 lr=3.000e-04 time=28.2s
# ----- EPOCH 6 -----
# [006] train=0.9758 val=0.8473 lr=2.999e-04 time=25.3s
# ----- EPOCH 7 -----
# [007] train=0.8981 val=0.8337 lr=2.997e-04 time=25.9s
# ----- EPOCH 8 -----
# [008] train=0.7851 val=0.6278 lr=2.993e-04 time=25.9s
# ----- EPOCH 9 -----
# [009] train=0.6154 val=0.5704 lr=2.987e-04 time=26.5s
# ----- EPOCH 10 -----
# [010] train=0.5488 val=0.4636 lr=2.980e-04 time=25.2s
# ----- EPOCH 11 -----
# [011] train=0.5565 val=0.5044 lr=2.971e-04 time=26.0s
# ----- EPOCH 12 -----
# [012] train=0.4928 val=0.4123 lr=2.960e-04 time=25.3s
# ----- EPOCH 13 -----
# [013] train=0.4514 val=0.4523 lr=2.948e-04 time=26.0s
# ----- EPOCH 14 -----
# [014] train=0.4421 val=0.3938 lr=2.934e-04 time=25.1s
# ----- EPOCH 15 -----
# [015] train=0.4276 val=0.3879 lr=2.919e-04 time=27.1s
# ----- EPOCH 16 -----
# [016] train=0.4109 val=0.4312 lr=2.902e-04 time=24.9s
# ----- EPOCH 17 -----
# [017] train=0.4220 val=0.3647 lr=2.883e-04 time=25.6s
# ----- EPOCH 18 -----
# [018] train=0.4020 val=0.3664 lr=2.864e-04 time=24.6s
# ----- EPOCH 19 -----
# [019] train=0.3957 val=0.3965 lr=2.842e-04 time=25.6s
# ----- EPOCH 20 -----
# [020] train=0.3870 val=0.3567 lr=2.819e-04 time=24.6s
# ----- EPOCH 21 -----
# [021] train=0.3812 val=0.3461 lr=2.795e-04 time=26.6s
# ----- EPOCH 22 -----
# [022] train=0.3748 val=0.3609 lr=2.769e-04 time=29.4s
# ----- EPOCH 23 -----
# [023] train=0.3772 val=0.3692 lr=2.742e-04 time=32.6s
# ----- EPOCH 24 -----
# [024] train=0.3786 val=0.3632 lr=2.714e-04 time=31.5s
# ----- EPOCH 25 -----
# [025] train=0.3722 val=0.3520 lr=2.684e-04 time=31.8s
# ----- EPOCH 26 -----
# [026] train=0.3713 val=0.3451 lr=2.653e-04 time=31.6s
# ----- EPOCH 27 -----
# [027] train=0.3709 val=0.3368 lr=2.620e-04 time=34.1s
# ----- EPOCH 28 -----
# [028] train=0.3585 val=0.3339 lr=2.587e-04 time=31.4s
# ----- EPOCH 29 -----
# [029] train=0.3527 val=0.3482 lr=2.552e-04 time=32.4s
# ----- EPOCH 30 -----
# [030] train=0.3454 val=0.3380 lr=2.516e-04 time=31.4s
# ----- EPOCH 31 -----
# [031] train=0.3445 val=0.3348 lr=2.479e-04 time=32.1s
# ----- EPOCH 32 -----
# [032] train=0.3397 val=0.3273 lr=2.441e-04 time=31.3s
# ----- EPOCH 33 -----
# [033] train=0.3324 val=0.3265 lr=2.402e-04 time=32.2s
# ----- EPOCH 34 -----
# [034] train=0.3313 val=0.3330 lr=2.361e-04 time=34.7s
# ----- EPOCH 35 -----
# [035] train=0.3279 val=0.3397 lr=2.320e-04 time=34.5s
# ----- EPOCH 36 -----
# [036] train=0.3331 val=0.3409 lr=2.278e-04 time=35.3s
# ----- EPOCH 37 -----
# [037] train=0.3266 val=0.3311 lr=2.236e-04 time=35.6s
# ----- EPOCH 38 -----
# [038] train=0.3192 val=0.3273 lr=2.192e-04 time=33.9s
# ----- EPOCH 39 -----
# [039] train=0.3148 val=0.3251 lr=2.148e-04 time=34.1s
# ----- EPOCH 40 -----
# [040] train=0.3127 val=0.3197 lr=2.103e-04 time=33.7s
# ----- EPOCH 41 -----
# [041] train=0.3049 val=0.3273 lr=2.057e-04 time=52.2s
# ----- EPOCH 42 -----
# [042] train=0.3009 val=0.3212 lr=2.010e-04 time=42.7s
# ----- EPOCH 43 -----
# [043] train=0.2998 val=0.3332 lr=1.964e-04 time=54.0s
# ----- EPOCH 44 -----
# [044] train=0.3034 val=0.3342 lr=1.916e-04 time=42.3s
# ----- EPOCH 45 -----
# [045] train=0.2986 val=0.3252 lr=1.868e-04 time=51.5s
# ----- EPOCH 46 -----
# [046] train=0.3000 val=0.3163 lr=1.820e-04 time=42.1s
# ----- EPOCH 47 -----
# [047] train=0.2887 val=0.3207 lr=1.771e-04 time=51.2s
# ----- EPOCH 48 -----
# [048] train=0.2911 val=0.3157 lr=1.722e-04 time=42.7s
# ----- EPOCH 49 -----
# [049] train=0.2801 val=0.3152 lr=1.673e-04 time=51.6s
# ----- EPOCH 50 -----
# [050] train=0.2781 val=0.3160 lr=1.624e-04 time=42.3s
# ----- EPOCH 51 -----
# [051] train=0.2777 val=0.3176 lr=1.574e-04 time=51.7s
# ----- EPOCH 52 -----
# [052] train=0.2748 val=0.3166 lr=1.525e-04 time=42.2s
# ----- EPOCH 53 -----
# [053] train=0.2757 val=0.3178 lr=1.475e-04 time=51.5s
# ----- EPOCH 54 -----
# [054] train=0.2735 val=0.3105 lr=1.426e-04 time=43.0s
# ----- EPOCH 55 -----
# [055] train=0.2666 val=0.3116 lr=1.376e-04 time=51.7s
# ----- EPOCH 56 -----
# [056] train=0.2616 val=0.3218 lr=1.327e-04 time=42.4s
# ----- EPOCH 57 -----
# [057] train=0.2604 val=0.3144 lr=1.278e-04 time=51.6s
# ----- EPOCH 58 -----
# [058] train=0.2565 val=0.3217 lr=1.229e-04 time=41.7s
# ----- EPOCH 59 -----
# [059] train=0.2585 val=0.3158 lr=1.180e-04 time=51.2s
# ----- EPOCH 60 -----
# [060] train=0.2537 val=0.3185 lr=1.132e-04 time=43.0s
# ----- EPOCH 61 -----
# [061] train=0.2499 val=0.3205 lr=1.084e-04 time=52.0s
# ----- EPOCH 62 -----
# [062] train=0.2505 val=0.3151 lr=1.036e-04 time=42.7s
# ----- EPOCH 63 -----
# [063] train=0.2437 val=0.3197 lr=9.896e-05 time=51.6s
# ----- EPOCH 64 -----
# [064] train=0.2458 val=0.3175 lr=9.432e-05 time=42.6s
# ----- EPOCH 65 -----
# [065] train=0.2423 val=0.3235 lr=8.975e-05 time=51.2s
# ----- EPOCH 66 -----
# [066] train=0.2410 val=0.3219 lr=8.524e-05 time=41.9s
# ----- EPOCH 67 -----
# [067] train=0.2354 val=0.3227 lr=8.080e-05 time=51.5s
# ----- EPOCH 68 -----
# [068] train=0.2302 val=0.3219 lr=7.644e-05 time=42.0s
# ----- EPOCH 69 -----
# [069] train=0.2281 val=0.3228 lr=7.215e-05 time=51.9s
# ----- EPOCH 70 -----
# [070] train=0.2254 val=0.3285 lr=6.796e-05 time=42.3s
# ----- EPOCH 71 -----
# [071] train=0.2214 val=0.3241 lr=6.385e-05 time=51.2s
# ----- EPOCH 72 -----
# [072] train=0.2178 val=0.3304 lr=5.984e-05 time=41.8s
# ----- EPOCH 73 -----
# [073] train=0.2145 val=0.3301 lr=5.592e-05 time=51.3s
# ----- EPOCH 74 -----
# [074] train=0.2123 val=0.3314 lr=5.211e-05 time=42.3s
# ----- EPOCH 75 -----
# [075] train=0.2104 val=0.3314 lr=4.841e-05 time=51.1s
# ----- EPOCH 76 -----
# [076] train=0.2072 val=0.3323 lr=4.481e-05 time=44.9s
# ----- EPOCH 77 -----
# [077] train=0.2044 val=0.3357 lr=4.134e-05 time=51.8s
# ----- EPOCH 78 -----
# [078] train=0.2025 val=0.3375 lr=3.798e-05 time=42.4s
# ----- EPOCH 79 -----
# [079] train=0.2005 val=0.3389 lr=3.474e-05 time=51.8s
# ----- EPOCH 80 -----
# [080] train=0.1969 val=0.3407 lr=3.163e-05 time=42.1s
# ----- EPOCH 81 -----
# [081] train=0.1943 val=0.3426 lr=2.865e-05 time=51.5s
# ----- EPOCH 82 -----
# [082] train=0.1927 val=0.3445 lr=2.580e-05 time=42.5s
# ----- EPOCH 83 -----
# [083] train=0.1917 val=0.3433 lr=2.309e-05 time=51.6s
# ----- EPOCH 84 -----
# [084] train=0.1895 val=0.3460 lr=2.051e-05 time=44.4s
# ----- EPOCH 85 -----
# [085] train=0.1878 val=0.3464 lr=1.808e-05 time=52.1s
# ----- EPOCH 86 -----
# [086] train=0.1864 val=0.3462 lr=1.579e-05 time=43.0s
# ----- EPOCH 87 -----
# [087] train=0.1844 val=0.3493 lr=1.365e-05 time=51.9s
# ----- EPOCH 88 -----
# [088] train=0.1830 val=0.3497 lr=1.166e-05 time=42.4s
# ----- EPOCH 89 -----
# [089] train=0.1817 val=0.3504 lr=9.815e-06 time=51.4s
# ----- EPOCH 90 -----
# [090] train=0.1807 val=0.3517 lr=8.127e-06 time=42.4s
# ----- EPOCH 91 -----
# [091] train=0.1795 val=0.3523 lr=6.595e-06 time=52.0s
# ----- EPOCH 92 -----
# [092] train=0.1789 val=0.3529 lr=5.219e-06 time=44.2s
# ----- EPOCH 93 -----
# [093] train=0.1782 val=0.3518 lr=4.001e-06 time=457.7s
# ----- EPOCH 94 -----
# [094] train=0.1779 val=0.3549 lr=2.943e-06 time=43.6s
# ----- EPOCH 95 -----
# [095] train=0.1774 val=0.3545 lr=2.046e-06 time=52.9s
# ----- EPOCH 96 -----
# [096] train=0.1770 val=0.3544 lr=1.310e-06 time=43.1s
# ----- EPOCH 97 -----
# [097] train=0.1767 val=0.3542 lr=7.376e-07 time=52.6s
# ----- EPOCH 98 -----
# [098] train=0.1765 val=0.3545 lr=3.280e-07 time=42.9s
# ----- EPOCH 99 -----
# [099] train=0.1763 val=0.3548 lr=8.201e-08 time=52.6s
# ----- EPOCH 100 -----
# [100] train=0.1763 val=0.3548 lr=0.000e+00 time=42.8s

# %%
#UNET PLUS W/ AUGS

import matplotlib.pyplot as plt

plt.figure(figsize=(6,3.5))
plt.plot(range(1, len(train_losses)+1), train_losses, label="train")
plt.plot(range(1, len(val_losses)+1),   val_losses,   label="val")
plt.xlabel("epoch"); plt.ylabel("loss"); plt.grid(True); plt.legend()
plt.title("Train vs Val Loss -- UNET PLUS NO AUGS")
plt.tight_layout()
plt.show()

# %%
# load best
model_core.load_state_dict(torch.load(SAVE_DIR / "best_unetplus_msu_wo_aug_drive.pth", map_location=DEVICE))
model_for_eval = model_core.eval()

# run your evaluation utility
print("UNET PLUS MSU WITH AUGS DRIVE DATASET")
evaluate_and_print(model_for_eval, test_dataloader=test_loader, device=DEVICE, threshold=0.5, compute_auc=True)
# Out:
# UNET PLUS MSU WITH AUGS DRIVE DATASET
# === Test Set Evaluation Metrics ===
# -- Macro (per-image mean) --
# Sensitivity    : 0.7987
# Specificity    : 0.9826
# Dice           : 0.8018
# Accuracy       : 0.9668
# IoU            : 0.6696
# Precision      : 0.8089
# FPR            : 0.0174
# FDR            : 0.1911
# clDice         : 0.8047
# Dice_thin      : 0.5113
# Dice_thick     : 0.6723
# ROC_AUC        : 0.9810
# PR_AUC         : 0.8865
# -- Micro (pooled over all pixels) --
# Sensitivity    : 0.7960
# Specificity    : 0.9826
# F1/Dice        : 0.8023
# Accuracy       : 0.9668
# IoU            : 0.6699
# Precision      : 0.8087
# FPR            : 0.0174
# FDR            : 0.1913
# ROC_AUC        : 0.9806
# PR_AUC         : 0.8844

# %%
visualize_samples(
    model=model_for_eval,
    dataloader=test_loader,
    n_rows=10,
    device=DEVICE,
    threshold=0.5,
    clamp_pred_with_fov=True,
    figsize_per_row=(12, 3),
)

# %% [markdown]
# # UNET PLUS MSU WITH AUGS RESULTS

# %%
import json, time, math
from torch.optim.lr_scheduler import LambdaLR

# --- optimizer / scaler / scheduler ---
optimizer = torch.optim.AdamW(model_core.parameters(), lr=3e-4, weight_decay=1e-4)
scaler    = torch.amp.GradScaler("cuda", enabled=(DEVICE=="cuda"))

EPOCHS = 100
warmup_epochs = 5

def lr_lambda(e):
    if e < warmup_epochs:
        return (e + 1) / warmup_epochs
    progress = (e - warmup_epochs) / max(1, EPOCHS - warmup_epochs)
    return 0.5 * (1 + math.cos(math.pi * progress))

scheduler = LambdaLR(optimizer, lr_lambda)

best_val = float("inf")

# --- lists to collect losses for plotting later ---
train_losses, val_losses = [], []

for epoch in range(1, EPOCHS+1):
    print(f"----- EPOCH {epoch} -----")
    if DEVICE == "cuda": torch.cuda.synchronize()
    t0 = time.time()

    tr_loss  = train_one_epoch(model_core, train_loader, optimizer, scaler, loss_fn)
    val_loss = validate_loss_only(model_core, test_loader, loss_fn)
    scheduler.step()

    if DEVICE == "cuda": torch.cuda.synchronize()
    print(f"[{epoch:03d}] train={tr_loss:.4f} val={val_loss:.4f} "
          f"lr={optimizer.param_groups[0]['lr']:.3e} time={(time.time()-t0):.1f}s")

    # record
    train_losses.append(float(tr_loss))
    val_losses.append(float(val_loss))

    # checkpoints
    torch.save(model_core.state_dict(), SAVE_DIR / LAST_PTH_W_AUGS)
    if val_loss < best_val:
        best_val = val_loss
        torch.save(model_core.state_dict(), SAVE_DIR / BEST_PTH_W_AUGS_PTH)
# Out:
# ----- EPOCH 1 -----
# [001] train=3.1282 val=1.1723 lr=1.200e-04 time=82.9s
# ----- EPOCH 2 -----
# [002] train=1.6012 val=1.2475 lr=1.800e-04 time=56.3s
# ----- EPOCH 3 -----
# [003] train=1.1880 val=1.4679 lr=2.400e-04 time=52.7s
# ----- EPOCH 4 -----
# [004] train=1.2971 val=3.4516 lr=3.000e-04 time=47.6s
# ----- EPOCH 5 -----
# [005] train=1.2949 val=1.5888 lr=3.000e-04 time=49.2s
# ----- EPOCH 6 -----
# [006] train=1.0920 val=1.0204 lr=2.999e-04 time=48.1s
# ----- EPOCH 7 -----
# [007] train=0.9621 val=0.8602 lr=2.997e-04 time=46.8s
# ----- EPOCH 8 -----
# [008] train=0.8662 val=0.7386 lr=2.993e-04 time=46.8s
# ----- EPOCH 9 -----
# [009] train=0.7215 val=0.8761 lr=2.987e-04 time=49.1s
# ----- EPOCH 10 -----
# [010] train=0.6366 val=0.4630 lr=2.980e-04 time=50.0s
# ----- EPOCH 11 -----
# [011] train=0.5370 val=0.4734 lr=2.971e-04 time=47.9s
# ----- EPOCH 12 -----
# [012] train=0.4921 val=0.4274 lr=2.960e-04 time=46.6s
# ----- EPOCH 13 -----
# [013] train=0.4650 val=0.3943 lr=2.948e-04 time=48.1s
# ----- EPOCH 14 -----
# [014] train=0.4434 val=0.4412 lr=2.934e-04 time=47.1s
# ----- EPOCH 15 -----
# [015] train=0.4412 val=0.3836 lr=2.919e-04 time=48.3s
# ----- EPOCH 16 -----
# [016] train=0.4353 val=0.3674 lr=2.902e-04 time=48.4s
# ----- EPOCH 17 -----
# [017] train=0.4335 val=0.3553 lr=2.883e-04 time=49.1s
# ----- EPOCH 18 -----
# [018] train=0.4064 val=0.3661 lr=2.864e-04 time=47.1s
# ----- EPOCH 19 -----
# [019] train=0.3981 val=0.3670 lr=2.842e-04 time=46.4s
# ----- EPOCH 20 -----
# [020] train=0.3976 val=0.3520 lr=2.819e-04 time=47.1s
# ----- EPOCH 21 -----
# [021] train=0.4042 val=0.3590 lr=2.795e-04 time=45.4s
# ----- EPOCH 22 -----
# [022] train=0.4199 val=0.3646 lr=2.769e-04 time=46.9s
# ----- EPOCH 23 -----
# [023] train=0.3938 val=0.3551 lr=2.742e-04 time=45.6s
# ----- EPOCH 24 -----
# [024] train=0.3919 val=0.3497 lr=2.714e-04 time=45.9s
# ----- EPOCH 25 -----
# [025] train=0.3819 val=0.3364 lr=2.684e-04 time=46.3s
# ----- EPOCH 26 -----
# [026] train=0.3950 val=0.3488 lr=2.653e-04 time=46.9s
# ----- EPOCH 27 -----
# [027] train=0.3822 val=0.3302 lr=2.620e-04 time=46.0s
# ----- EPOCH 28 -----
# [028] train=0.3748 val=0.3351 lr=2.587e-04 time=45.2s
# ----- EPOCH 29 -----
# [029] train=0.3805 val=0.3374 lr=2.552e-04 time=46.1s
# ----- EPOCH 30 -----
# [030] train=0.3780 val=0.3318 lr=2.516e-04 time=46.4s
# ----- EPOCH 31 -----
# [031] train=0.3731 val=0.3386 lr=2.479e-04 time=45.0s
# ----- EPOCH 32 -----
# [032] train=0.3717 val=0.3296 lr=2.441e-04 time=44.9s
# ----- EPOCH 33 -----
# [033] train=0.3700 val=0.3375 lr=2.402e-04 time=45.8s
# ----- EPOCH 34 -----
# [034] train=0.3558 val=0.3389 lr=2.361e-04 time=45.4s
# ----- EPOCH 35 -----
# [035] train=0.3642 val=0.3205 lr=2.320e-04 time=44.8s
# ----- EPOCH 36 -----
# [036] train=0.3584 val=0.3324 lr=2.278e-04 time=44.6s
# ----- EPOCH 37 -----
# [037] train=0.3597 val=0.3213 lr=2.236e-04 time=44.6s
# ----- EPOCH 38 -----
# [038] train=0.3526 val=0.3310 lr=2.192e-04 time=44.5s
# ----- EPOCH 39 -----
# [039] train=0.3549 val=0.3223 lr=2.148e-04 time=45.4s
# ----- EPOCH 40 -----
# [040] train=0.3550 val=0.3241 lr=2.103e-04 time=47.6s
# ----- EPOCH 41 -----
# [041] train=0.3505 val=0.3173 lr=2.057e-04 time=46.9s
# ----- EPOCH 42 -----
# [042] train=0.3476 val=0.3122 lr=2.010e-04 time=45.9s
# ----- EPOCH 43 -----
# [043] train=0.3491 val=0.3383 lr=1.964e-04 time=46.1s
# ----- EPOCH 44 -----
# [044] train=0.3586 val=0.3100 lr=1.916e-04 time=45.9s
# ----- EPOCH 45 -----
# [045] train=0.3454 val=0.3214 lr=1.868e-04 time=51.4s
# ----- EPOCH 46 -----
# [046] train=0.3506 val=0.3098 lr=1.820e-04 time=46.8s
# ----- EPOCH 47 -----
# [047] train=0.3421 val=0.3152 lr=1.771e-04 time=49.5s
# ----- EPOCH 48 -----
# [048] train=0.3544 val=0.3116 lr=1.722e-04 time=46.0s
# ----- EPOCH 49 -----
# [049] train=0.3426 val=0.3147 lr=1.673e-04 time=46.2s
# ----- EPOCH 50 -----
# [050] train=0.3381 val=0.3130 lr=1.624e-04 time=44.7s
# ----- EPOCH 51 -----
# [051] train=0.3369 val=0.3125 lr=1.574e-04 time=45.8s
# ----- EPOCH 52 -----
# [052] train=0.3383 val=0.3081 lr=1.525e-04 time=45.7s
# ----- EPOCH 53 -----
# [053] train=0.3355 val=0.3176 lr=1.475e-04 time=47.2s
# ----- EPOCH 54 -----
# [054] train=0.3365 val=0.3050 lr=1.426e-04 time=46.3s
# ----- EPOCH 55 -----
# [055] train=0.3289 val=0.3010 lr=1.376e-04 time=46.7s
# ----- EPOCH 56 -----
# [056] train=0.3280 val=0.3030 lr=1.327e-04 time=47.8s
# ----- EPOCH 57 -----
# [057] train=0.3302 val=0.3013 lr=1.278e-04 time=46.8s
# ----- EPOCH 58 -----
# [058] train=0.3275 val=0.3005 lr=1.229e-04 time=46.8s
# ----- EPOCH 59 -----
# [059] train=0.3272 val=0.3014 lr=1.180e-04 time=46.7s
# ----- EPOCH 60 -----
# [060] train=0.3263 val=0.2995 lr=1.132e-04 time=47.2s
# ----- EPOCH 61 -----
# [061] train=0.3229 val=0.3005 lr=1.084e-04 time=47.1s
# ----- EPOCH 62 -----
# [062] train=0.3227 val=0.2981 lr=1.036e-04 time=47.3s
# ----- EPOCH 63 -----
# [063] train=0.3212 val=0.3024 lr=9.896e-05 time=48.1s
# ----- EPOCH 64 -----
# [064] train=0.3267 val=0.3026 lr=9.432e-05 time=49.0s
# ----- EPOCH 65 -----
# [065] train=0.3216 val=0.3025 lr=8.975e-05 time=48.9s
# ----- EPOCH 66 -----
# [066] train=0.3255 val=0.2977 lr=8.524e-05 time=47.9s
# ----- EPOCH 67 -----
# [067] train=0.3200 val=0.3017 lr=8.080e-05 time=46.8s
# ----- EPOCH 68 -----
# [068] train=0.3188 val=0.2964 lr=7.644e-05 time=47.4s
# ----- EPOCH 69 -----
# [069] train=0.3143 val=0.2971 lr=7.215e-05 time=46.9s
# ----- EPOCH 70 -----
# [070] train=0.3153 val=0.3002 lr=6.796e-05 time=47.0s
# ----- EPOCH 71 -----
# [071] train=0.3172 val=0.2973 lr=6.385e-05 time=49.0s
# ----- EPOCH 72 -----
# [072] train=0.3150 val=0.2980 lr=5.984e-05 time=49.6s
# ----- EPOCH 73 -----
# [073] train=0.3178 val=0.2959 lr=5.592e-05 time=47.1s
# ----- EPOCH 74 -----
# [074] train=0.3177 val=0.2972 lr=5.211e-05 time=46.3s
# ----- EPOCH 75 -----
# [075] train=0.3136 val=0.2983 lr=4.841e-05 time=46.8s
# ----- EPOCH 76 -----
# [076] train=0.3127 val=0.2963 lr=4.481e-05 time=46.7s
# ----- EPOCH 77 -----
# [077] train=0.3114 val=0.2971 lr=4.134e-05 time=46.8s
# ----- EPOCH 78 -----
# [078] train=0.3101 val=0.2947 lr=3.798e-05 time=47.5s
# ----- EPOCH 79 -----
# [079] train=0.3102 val=0.2967 lr=3.474e-05 time=57.4s
# ----- EPOCH 80 -----
# [080] train=0.3108 val=0.2951 lr=3.163e-05 time=47.4s
# ----- EPOCH 81 -----
# [081] train=0.3075 val=0.2955 lr=2.865e-05 time=46.2s
# ----- EPOCH 82 -----
# [082] train=0.3049 val=0.2940 lr=2.580e-05 time=45.6s
# ----- EPOCH 83 -----
# [083] train=0.3096 val=0.2941 lr=2.309e-05 time=45.3s
# ----- EPOCH 84 -----
# [084] train=0.3074 val=0.2967 lr=2.051e-05 time=46.0s
# ----- EPOCH 85 -----
# [085] train=0.3048 val=0.2958 lr=1.808e-05 time=46.6s
# ----- EPOCH 86 -----
# [086] train=0.3041 val=0.2938 lr=1.579e-05 time=45.8s
# ----- EPOCH 87 -----
# [087] train=0.3044 val=0.2940 lr=1.365e-05 time=45.4s
# ----- EPOCH 88 -----
# [088] train=0.3040 val=0.2970 lr=1.166e-05 time=45.0s
# ----- EPOCH 89 -----
# [089] train=0.3060 val=0.2954 lr=9.815e-06 time=48.9s
# ----- EPOCH 90 -----
# [090] train=0.3030 val=0.2952 lr=8.127e-06 time=47.5s
# ----- EPOCH 91 -----
# [091] train=0.3022 val=0.2948 lr=6.595e-06 time=47.4s
# ----- EPOCH 92 -----
# [092] train=0.3042 val=0.2952 lr=5.219e-06 time=44.9s
# ----- EPOCH 93 -----
# [093] train=0.3036 val=0.2952 lr=4.001e-06 time=44.2s
# ----- EPOCH 94 -----
# [094] train=0.3013 val=0.2951 lr=2.943e-06 time=43.6s
# ----- EPOCH 95 -----
# [095] train=0.3009 val=0.2951 lr=2.046e-06 time=43.5s
# ----- EPOCH 96 -----
# [096] train=0.3032 val=0.2949 lr=1.310e-06 time=46.7s
# ----- EPOCH 97 -----
# [097] train=0.3019 val=0.2947 lr=7.376e-07 time=45.0s
# ----- EPOCH 98 -----
# [098] train=0.3036 val=0.2947 lr=3.280e-07 time=46.0s
# ----- EPOCH 99 -----
# [099] train=0.3037 val=0.2947 lr=8.201e-08 time=46.2s
# ----- EPOCH 100 -----
# [100] train=0.3012 val=0.2947 lr=0.000e+00 time=45.4s

# %%
#UNET PLUS MSU W AUGS DRIVE

import matplotlib.pyplot as plt

plt.figure(figsize=(6,3.5))
plt.plot(range(1, len(train_losses)+1), train_losses, label="train")
plt.plot(range(1, len(val_losses)+1),   val_losses,   label="val")
plt.xlabel("epoch"); plt.ylabel("loss"); plt.grid(True); plt.legend()
plt.title("Train vs Val Loss -- UNET PLUS NO AUGS")
plt.tight_layout()
plt.show()

# %%
# load best
model_core.load_state_dict(torch.load(SAVE_DIR / BEST_PTH_W_AUGS_PTH, map_location=DEVICE))
model_for_eval = model_core.eval()

# run your evaluation utility
print("UNET PLUS MSU WITH AUGS DRIVE DATASET")
evaluate_and_print(model_for_eval, test_dataloader=test_loader, device=DEVICE, threshold=0.5, compute_auc=True)
# Out:
# UNET PLUS MSU WITH AUGS DRIVE DATASET
# === Test Set Evaluation Metrics ===
# -- Macro (per-image mean) --
# Sensitivity    : 0.7992
# Specificity    : 0.9845
# Dice           : 0.8106
# Accuracy       : 0.9685
# IoU            : 0.6819
# Precision      : 0.8264
# FPR            : 0.0155
# FDR            : 0.1736
# clDice         : 0.8113
# Dice_thin      : 0.5201
# Dice_thick     : 0.6804
# ROC_AUC        : 0.9836
# PR_AUC         : 0.8968
# -- Micro (pooled over all pixels) --
# Sensitivity    : 0.7963
# Specificity    : 0.9845
# F1/Dice        : 0.8109
# Accuracy       : 0.9685
# IoU            : 0.6820
# Precision      : 0.8261
# FPR            : 0.0155
# FDR            : 0.1739
# ROC_AUC        : 0.9832
# PR_AUC         : 0.8943

# %%
visualize_samples(
    model=model_for_eval,
    dataloader=test_loader,
    n_rows=10,
    device=DEVICE,
    threshold=0.5,
    clamp_pred_with_fov=True,
    figsize_per_row=(12, 3),
)
